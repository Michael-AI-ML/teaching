# %% [markdown]
# ❗❗❗❗ **READ EVERY Word of text** as a How-To.
#
# The python scripts (i.e., the code syntax) are good to review, but read the directions for every code cell. ❗❗❗❗

# %% [markdown]
# **STEP 1 (do before you run anything!)**
#
# Before you run any of this notebook, you should make a copy.
#
# Click "File" -> "Save a copy in Drive"
#
# Save it to your Google Drive.
#
# The default name will be
#
# `Copy of DataSciencePythonCrISPDM.ipynb`
#
# but you can name it anything you want.

# %% [markdown]
# # Intro

# %% [markdown]
# *Every Notebook and project should have a purpose.*
#
# The purpose of this notebook is to showcase how to apply the **Cross Industrial Stanadard Process for Data Modeling** and using Python notebooks.
#
#
# Author is Michael McCarthy (mbmccart@utica.edu)
#
# Feedback Welcomed

# %% [markdown]
# # Running Code Cells

# %% [markdown]
# ✅ Python runs code from top to bottom, left to right.
#
# ✅ A python notebook like this one is the same but each *code* cell can be run independently so the order you run the cells matters.

# %% [markdown]
# ✅ There are many ways to run code cells.
#
# ✅ For now, run each code cell by clicking the play button on each code cell
# or typing Shift + Enter.

# %%
# Run these cells in order
# We will assign a number to a variable we will call 'number_variable'
number_variable = 7100
# The notebook will hold this value in memory

# %%
# Let's take a look at the variable
print("the number assigned to the 'number_variable' is")
print(number_variable)
# Out:
# the number assigned to the 'number_variable' is
# 7

# %%
# The notebook will hold that value in memory until it is overwritten.
# Let's overwrite it now
number_variable = 22

# %%
# Let's take another look at the variable after we update it (i.e., over-write the variable)
# NOTE that this is the same variable we assigned before: `number_variable`
print("the number assigned to the 'number_variable' is \n" , number_variable)

# NOTE: We got a similar format print output compared to code cell 3 with one print function using the `\n` and the comma
# Out:
# the number assigned to the 'number_variable' is
#  22

# %%
# The order that cells runs matters.
# if I rerun the first cell again, I will overwrite the value again.
# Try this now:
# 1) Rerun the cell that has "number_variable = 7100"
print(number_variable)
# is the value 1 or 22?
# Out:
# 22

# %%
# The variable is a number so we can use it in equations
new_number_variable = number_variable + 1
print(new_number_variable)
# Out:
# 23

# %% [markdown]
# # Python Basics

# %%
# Any line of code with a hash sign (also known as the pound sign) is a comment and will NOT as code.
#In google Colab, comments turn the font to green.
""" The tripple quotes, seen here are comments that carry on
over several lines.
The whole cell can be commented out """
# Out:
# ' The tripple quotes, seen here are comments that carry on\nover several lines.\nThe whole cell can be commented out '

# %% [markdown]
# ✅ This notebook is like a google doc but connected compute resources.
#
# ✅ If the notebook is idle too long, you have to reconnect and run all the cells again from top to bottom.

# %%
# Indenting in Python matters
# For example, a forward loop only works when the indenting is correct:
for x in range(10):
  print(x*(x+1))

# A for loop will not work this without the indent on the second line
# it will cause an error
"""
for x in range(10):
print(x*(x+1))
"""
# Out:
# 0
# 2
# 6
# 12
# 20
# 30
# 42
# 56
# 72
# 90
# '\nfor x in range(10):\nprint(x*(x+1))\n'

# %%
# Each code cell will receive a number in the empty bracket after it is run showcasing the order in which it is run.
# If the cell is run again, the cell number will be the most recent number (that is, the higher number)
print("If you ran all the prevous code cells, this cell should have the number 9")
# NOTE: sometimes the cell number is hidden under the "play" icon.
# To see the code cell number, move your cursor away from the play icon to reveal the number underneath.
# Out:
# If you ran all the prevous code cells, this cell should have the number 8

# %% [markdown]
# **Quick Note**, instead of having 1 code cell that does 8 things, it is better to have 8 code ceslls that each do one things.
#
# This allows you to systematically build and check each step of your work.

# %% [markdown]
# ## Libarary Loading

# %% [markdown]
# ✅ The basic Python loaded as default into Colab is robust, but there are some extra packages (e.g., libraries) that we need to load to make sure we can do all the functions we need.

# %%
# Python interactive development enviroments (IDE) come with base Python 3.x but
#     certain modules, packages, and libraries as need.

# Pandas is the main way we will work with the dataframes
# https://pandas.pydata.org/docs/getting_started/index.html#getting-started
import pandas as pd
# pandas defaults to not showing all rows, this pd (pandas) option update ensures all rows are shown
# for larger datasets, update 'None' with a specific number; for now, just leav it as "None"
pd.set_option('display.max_rows', None)
# pandas defaults to not showing all columns, this pd (pandas) option update ensures all columns are shown
pd.set_option('display.max_columns', None)
#numpy is the "The fundamental package for scientific computing with Python"
# https://numpy.org/
import numpy as np
# To make outputs more understandable, remove the scientific notation
np.set_printoptions(suppress=True)

# %%
# Packages & Libraries needed to load data from Google Drive
# For this class, ALL Data will be loaded from Google Drive.
# TIP: Load data just once.
# https://pypi.org/project/PyDrive2/

# !pip install -U -q PyDrive2 # sometimes a library needs to be installed before it is installed
from pydrive2.auth import GoogleAuth
from pydrive2.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
# Authenticate users to have acces to google Drive.
# Google will make you authorize access to connect directly to the Google Drive
# The process might change, just approve the access by approving or by clicking
# "Allow", "Continue", and/or selecting your Utica Account (not your personal email).

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %% [markdown]
# ## DATA Loading

# %% [markdown]
# ✅ To load data from Google Drive, we have to point the notebook to the specific file by ID and name. Below, we are loading example data that you will use for this notebook, but the code cell also provides the step-by-step instructions to update this data loading code cell to access any datafile in your Google Drive or shared via Google Drive.

# %% [markdown]
# **FOR most Utica University DSC courses assignments, data MUST be loaded from Google Drive**
#
# ✅ Load data just once.
#
# ✅ The file type matters: the code is a little different if you import an Excel file (xls) or a text file (txt).

# %%
## You will run this cell with no updates to load the example data,
## but here are the steps to load any CSV file from Google Drive.

# 1) Open the Google Drive with the Data
# 2) Find your assigned dataset
# 3) Click "share"
# 4) Copy link
# 5) Paste link here:
#    The link should look something like this: https://drive.google.com/file/d/1WVluSCNJ--RS1zqQ_0EJScPgurw9CmHj/view?usp=sharing
# 6) Copy the unique file id, for the example above, it looks like this: 1WVluSCNJ--RS1zqQ_0EJScPgurw9CmHj
#   Hint: the file id is all the content between the forward slashes slashes /  including the letter, numbers, dashes, and underscores
# 7) In the next code line below, replace the unique google doc file id for the example data with the unique file id for your data.
file_id = '1WVluSCNJ--RS1zqQ_0EJScPgurw9CmHj' # replace the id with id of file you want to access
downloaded = drive.CreateFile({'id':file_id})

# 8) Update the file name below to match the file name in the Google Drive Folder by replacing 'Heart_Synthetic.csv' with your file name.
# Hint, you must have single or double quotes around the file name.
file_name = 'Heart_Synthetic.csv' # Update needed here, replace the file name with the id of file you want
downloaded.GetContentFile(file_name)
df = pd.read_csv(file_name)

# 9) Run all cells before this code cell (Hint: Shortcut = CTRL + F8)
# 10) Run this cell (click the play button or Shift + Enter)

# %% [markdown]
# ## Testing Each code Block
# In Python and coding in general, you have to test your code at each step; the fancy name for this is "unit testing".
#
# You have to run the code to see if the output is what you expected.
#
# It is better to have 8 code cells doing 1 thing each than 1 code cell doing 8 things.

# %%
# If there is no output, use a print() statement to generate an output.
# Step 11 of data loading: Check the data output is what you expected.
print(f"{file_name} Data Shape: ",df.shape)
print(df.head())
# Out:
# Heart_Synthetic.csv Data Shape:  (303, 18)
#    RecordID  age  ca  trestbps  chol  thalach  oldpeak          SSN  \
# 0         1   63   0       145   233      150      2.3  616-95-2670
# 1         2   37   0       130   250      187      3.5  579-42-1915
# 2         3   41   0       130   204      172      1.4  332-33-7829
# 3         4   56   0       120   236      178      0.8  436-60-6488
# 4         5   57   0       120   354      163      0.6  856-35-7953
#
#   SEX_string            CP_string         RESTECG_string EXANG_string  \
# 0       male  asymptomatic angina                 normal           no
# 1       male           non-angina  ST-T wave abnormality           no
# 2     female      atypical angina                 normal           no
# 3       male      atypical angina  ST-T wave abnormality           no
# 4     female       typical angina  ST-T wave abnormality          yes
#
#   FBS_string SLOPE_string   THAL_string TARGET_string Race_String  incident
# 0       HIGH    upsloping        normal  asymptomatic       white     3.803
# 1        low    upsloping  fixed defect  asymptomatic       black     2.815
# 2        low  downsloping  fixed defect  asymptomatic       white     1.854
# 3        low  downsloping  fixed defect  asymptomatic       black    23.172
# 4        low  downsloping  fixed defect  asymptomatic       white    13.378

# %% [markdown]
# ## Exploratory Data Analysis (EDA) | Data Understanding

# %% [markdown]
# ✅ Once the data is loaded, we need to understand it.
#
# ✅ This is the "Data Understanding" portion of the *Cross-Industry Standard process for Data Mining* (CrISP-DM)

# %%
# Load the descriptive statistics into a dataframe called "descriptive_statistics_view"
# Similar to when we assigned the value of 1 to 'number_variable'
# the equal sign is used to assign the descriptive statistics to a new dataframe
descriptive_statistics_view = df.describe()

# %%
# Because there was no output in the step above,
# we need to review the show the descriptive_statistics_view
descriptive_statistics_view
# Out:
#          RecordID         age          ca    trestbps        chol     thalach  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean   152.000000   54.366337    0.663366  131.623762  246.264026  149.646865
# std     87.612784    9.082101    0.934375   17.538143   51.830751   22.905161
# min      1.000000   29.000000    0.000000   94.000000  126.000000   71.000000
# 25%     76.500000   47.500000    0.000000  120.000000  211.000000  133.500000
# 50%    152.000000   55.000000    0.000000  130.000000  240.000000  153.000000
# 75%    227.500000   61.000000    1.000000  140.000000  274.500000  166.000000
# max    303.000000   77.000000    3.000000  200.000000  564.000000  202.000000
#
#           oldpeak    incident
# count  303.000000  303.000000
# mean     1.039604    6.053644
# std      1.161075   13.077695
# min      0.000000    0.038000
# 25%      0.000000    1.427500
# 50%      0.800000    2.442000
# 75%      1.600000    4.445000
# max      6.200000  138.338000

# %%
# Notice how the view changes using a print statement to see the same data
print(descriptive_statistics_view)
# Out:
#          RecordID         age          ca    trestbps        chol     thalach  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean   152.000000   54.366337    0.663366  131.623762  246.264026  149.646865
# std     87.612784    9.082101    0.934375   17.538143   51.830751   22.905161
# min      1.000000   29.000000    0.000000   94.000000  126.000000   71.000000
# 25%     76.500000   47.500000    0.000000  120.000000  211.000000  133.500000
# 50%    152.000000   55.000000    0.000000  130.000000  240.000000  153.000000
# 75%    227.500000   61.000000    1.000000  140.000000  274.500000  166.000000
# max    303.000000   77.000000    3.000000  200.000000  564.000000  202.000000
#
#           oldpeak    incident
# count  303.000000  303.000000
# mean     1.039604    6.053644
# std      1.161075   13.077695
# min      0.000000    0.038000
# 25%      0.000000    1.427500
# 50%      0.800000    2.442000
# 75%      1.600000    4.445000
# max      6.200000  138.338000

# %%
# If you want to improve readability and display it neatly
# we need to import a library and configure the function
# https://pypi.org/project/tabulate/
import tabulate as tb

print(tb.tabulate(descriptive_statistics_view, headers='keys', tablefmt='pretty'))
# Out:
# +-------+-------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |       |     RecordID      |        age         |         ca         |      trestbps      |        chol        |      thalach       |      oldpeak       |      incident      |
# +-------+-------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# | count |       303.0       |       303.0        |       303.0        |       303.0        |       303.0        |       303.0        |       303.0        |       303.0        |
# | mean  |       152.0       | 54.366336633663366 | 0.6633663366336634 | 131.62376237623764 | 246.26402640264027 | 149.64686468646866 | 1.0396039603960396 | 6.053643564356435  |
# |  std  | 87.61278445523804 | 9.082100989837858  | 0.9343754622345026 | 17.53814281351709  | 51.830750987930045 | 22.905161114914087 | 1.1610750220686343 | 13.077694976271639 |
# |  min  |        1.0        |        29.0        |        0.0         |        94.0        |       126.0        |        71.0        |        0.0         |       0.038        |
# |  25%  |       76.5        |        47.5        |        0.0         |       120.0        |       211.0        |       133.5        |        0.0         |       1.4275       |
# |  50%  |       152.0       |        55.0        |        0.0         |       130.0        |       240.0        |       153.0        |        0.8         |       2.442        |
# |  75%  |       227.5       |        61.0        |        1.0         |       140.0        |       274.5        |       166.0        |        1.6         |       4.445        |
# |  max  |       303.0       |        77.0        |        3.0         |       200.0        |       564.0        |       202.0        |        6.2         |      138.338       |
# +-------+-------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+

# %%
# prompt: identify all the unique values in each categorical variable, test for nominal varirables by counting the unique values and if they are with 50% of the total number or data rows,  remove the variable from print statement

# Identify nominal variables and filter based on unique value counts
for col in df.select_dtypes(include=['object']):
    unique_counts = df[col].nunique()
    if unique_counts <= 0.5 * len(df):  # Check if unique values are within 50% of total rows
        print(f"Unique values for {col}:")
        print(df[col].unique())
        print("-" * 20)
    else:
        print(f"Variable '{col}' has too many unique values ({unique_counts}) to be considered nominal and will be excluded from detailed analysis")
# Out:
# Variable 'SSN' has too many unique values (303) to be considered nominal and will be excluded from detailed analysis
# Unique values for SEX_string:
# ['male' 'female']
# --------------------
# Unique values for CP_string:
# ['asymptomatic angina' 'non-angina' 'atypical angina' 'typical angina']
# --------------------
# Unique values for RESTECG_string:
# ['normal' 'ST-T wave abnormality' 'left ventricular hypertrophy']
# --------------------
# Unique values for EXANG_string:
# ['no' 'yes']
# --------------------
# Unique values for FBS_string:
# ['HIGH' 'low']
# --------------------
# Unique values for SLOPE_string:
# ['upsloping' 'downsloping' 'flat']
# --------------------
# Unique values for THAL_string:
# ['normal' 'fixed defect' 'reversable defect' nan]
# --------------------
# Unique values for TARGET_string:
# ['asymptomatic' 'heart disease']
# --------------------
# Unique values for Race_String:
# ['white' 'black' 'asian']
# --------------------

# %%
# Create mappings for ordinal variables
# Ordinal variable have structure and *should* be treated differently than nominal variables.
SLOPE_string_mapping = {'upsloping': 1, 'downsloping': -1, 'flat': 0}

# Before applying the mapping, check if the columns exist
if 'SLOPE_string' in df.columns: # Changed 'ExterQual' to 'Exter Qual' to match the column name in the DataFrame
    df['ExterQual_numeric'] = df['SLOPE_string'].map(SLOPE_string_mapping)
else:
    print("Warning: 'SLOPE_string' column not found in the DataFrame.")
# Check if the variable unique values are updated?
print(df["ExterQual_numeric"].unique())
# Out:
# [ 1 -1  0]

# %%
# If the oridnal data was updated, drop the string variable
# prompt: drop SLOPE_string from df

if 'SLOPE_string' in df.columns:
    print("Data Frame shape before drop ", df.shape[1]) # the shape reports rows and columns, we want just the colunns, that is why we index it at 1
    df = df.drop('SLOPE_string', axis=1)  # axis defines rows or columns: 1 = colunmns.
    print("'SLOPE_string' column dropped successfully.")
    print("Data Frame shape after drop ", df.shape[1])
else:
    print("Warning: 'SLOPE_string' column not found in the DataFrame.")
# Out:
# Data Frame shape before drop  19
# 'SLOPE_string' column dropped successfully.
# Data Frame shape after drop  18

# %% [markdown]
# ## Using prompts to build Code (i.e., [Vibe Coding](http://en.wikipedia.org/wiki/Vibe_coding/))
#
# ✅ When using prompts to build code, there are several steps that **must** be completed to ensure your work is good, and you are learning what Python is doing to your data.
#
# 1.   **Write a specific prompt** telling that identifies the input and expected output. You can even tell it how: Example:
# Build a swarmplot using seaborn for 'Salary', 'Position', and 'Sex' variables in df.
# 2.   **Review the prompt**. Take a second to understand what is going in.
# 3.   **Generate the Code.**
# 4.   **Use "Explain Code".** Make sure you understand the code.
# 5.   **Run the code cell.**
# 6.   **Review the output.** Is it what you expected?
# 7.   **Retain the prompt** to show where the code came from (any questions on how to document, see the course "Coding Policy").
#
# ✅ Below is an example.
#
# I entered the the prompt, now you use the "explain code" option. In the code cell, click the three dots to reveal "Explain Code", click on it.

# %% [markdown]
# # Wrangling | Data Preparation

# %% [markdown]
# ✅ The data can be very "dirty" or not in the form we need it to be so we do considerable data wrangling.
#
# ✅ This is the "Data Preparation" step in the CriSP-DM.

# %%
# prompt: review df for a list of multiple variable names from a list and drops the variables from the df. the defualt list is just one variable 'RecordID'
# NOTE, this was my third prompt. The first two were so vague that Gemini had a **very** long function.
"""
LLMs, like Geminin, will often build a function as part of the code it generates.
This is great because it is reusable within the notebook or can be brought over to another notebook.
It is important that the function is run, not just defined.
Running the function is best done in a seperate cell after the function is defined.
"""
def drop_variables(df, variables_to_drop=['RecordID']):
    """
    Reviews a Pandas DataFrame for a list of variable names and drops them.

    Args:
        df: The input DataFrame.
        variables_to_drop: A list of variable names to drop. Defaults to ['RecordID'].

    Returns:
        A new DataFrame with the specified variables removed, or the original DataFrame if no variables are found.
        Prints a message indicating which variables were dropped or if none were found.
    """

    variables_dropped = []             # defines an empty list to add dropped variables to
    for var in variables_to_drop:      # for loop to look at each varible in the list
        if var in df.columns:          # if test to look if the variable name is in the dataframe's columns
            df = df.drop(var, axis=1)  # drop the variable from the dataframe
            variables_dropped.append(var)  # add the variable to the list of dropped variables

    if variables_dropped:   # if test defaults to "TRUE" so if the list is not blank, it will do the rest of the if statement
        print(f"Variables dropped: {variables_dropped}")
    else:                   # else statements are optional, but should be used
        print("No variables to drop found in the DataFrame.")

    # Final Notes:
    """
    Gemini did not identify the much simplier way to do this.
    However, this one line of coade does not build or report the variables_dropped list.
    """
    # df = df.drop(variables_to_drop, errors= 'ignore', axis=1)
    """ This is how it would look in a production enviornment, to prvent the extra memory needed to overwrite the df. """
    # df.drop(columns=variables_to_drop, errors='ignore', inplace=True) # `axis=1` indicates columns and removed because it is the default, therefore not needed

    return df               # identifies that the fucntion returns the original df modified

# %%
# Apply the fution just defined above, it needs to be rund to apply it to the data.
# To run for a different pdateset, just update variables in the list
# in this case, we are removing numerical that act as identification variables for patients.
df = drop_variables(df, variables_to_drop=['RecordID', 'SSN']) # SSN was added to remove list due to privacy concerns
# Out:
# Variables dropped: ['RecordID', 'SSN']

# %%
# Assess the data after the drop and look at the data types.
# Make sure we have numbers, not just strings because a CSV can often load all variables as strings.
print("\nTraining DATA\n")
print(df.dtypes)
# Out:
# Training DATA
#
# age                    int64
# ca                     int64
# trestbps               int64
# chol                   int64
# thalach                int64
# oldpeak              float64
# SEX_string            object
# CP_string             object
# RESTECG_string        object
# EXANG_string          object
# FBS_string            object
# THAL_string           object
# TARGET_string         object
# Race_String           object
# incident             float64
# ExterQual_numeric      int64
# dtype: object

# %%
# Call the dataframe to show the variables and open Interactive table in Colab
# NOTE, if you scroll all the way to the right, click the Table icon to view an "interactive sheet" that acts like an excel spreadsheet
# The plot icon will generate many suggested plots, only some of them are worth using in your analysis.
df
# After you you run and view your df, you should see the "Next steps:" options under the datframe output. These are wise to use for the very first steps of your EDA.
# After you you "View recommended plots", be sure to dig deeper with your own plots
# Out:
#      age  ca  trestbps  chol  thalach  oldpeak SEX_string  \
# 0     63   0       145   233      150      2.3       male
# 1     37   0       130   250      187      3.5       male
# 2     41   0       130   204      172      1.4     female
# 3     56   0       120   236      178      0.8       male
# 4     57   0       120   354      163      0.6     female
# 5     57   0       140   192      148      0.4       male
# 6     56   0       140   294      153      1.3     female
# 7     44   0       120   263      173      0.0       male
# 8     52   0       172   199      162      0.5       male
# 9     57   0       150   168      174      1.6       male
# 10    54   0       140   239      160      1.2       male
# 11    48   0       130   275      139      0.2     female
# 12    49   0       130   266      171      0.6       male
# 13    64   0       110   211      144      1.8       male
# 14    58   0       150   283      162      1.0     female
# 15    50   0       120   219      158      1.6     female
# 16    58   0       120   340      172      0.0     female
# 17    66   0       150   226      114      2.6     female
# 18    43   0       150   247      171      1.5       male
# 19    69   2       140   239      151      1.8     female
# 20    59   0       135   234      161      0.5       male
# 21    44   0       130   233      179      0.4       male
# 22    42   0       140   226      178      0.0       male
# 23    61   0       150   243      137      1.0       male
# 24    40   0       140   199      178      1.4       male
# 25    71   2       160   302      162      0.4     female
# 26    59   0       150   212      157      1.6       male
# 27    51   0       110   175      123      0.6       male
# 28    65   1       140   417      157      0.8     female
# 29    53   0       130   197      152      1.2       male
# 30    41   1       105   198      168      0.0     female
# 31    65   0       120   177      140      0.4       male
# 32    44   0       130   219      188      0.0       male
# 33    54   1       125   273      152      0.5       male
# 34    51   1       125   213      125      1.4       male
# 35    46   0       142   177      160      1.4     female
# 36    54   0       135   304      170      0.0     female
# 37    54   0       150   232      165      1.6       male
# 38    65   0       155   269      148      0.8     female
# 39    65   0       160   360      151      0.8     female
# 40    51   1       140   308      142      1.5     female
# 41    48   0       130   245      180      0.2       male
# 42    45   0       104   208      148      3.0       male
# 43    53   0       130   264      143      0.4     female
# 44    39   0       140   321      182      0.0       male
# 45    52   0       120   325      172      0.2       male
# 46    44   0       140   235      180      0.0       male
# 47    47   0       138   257      156      0.0       male
# 48    53   0       128   216      115      0.0     female
# 49    53   0       138   234      160      0.0     female
# 50    51   0       130   256      149      0.5     female
# 51    66   0       120   302      151      0.4       male
# 52    62   3       130   231      146      1.8       male
# 53    44   0       108   141      175      0.6     female
# 54    63   0       135   252      172      0.0     female
# 55    52   1       134   201      158      0.8       male
# 56    48   0       122   222      186      0.0       male
# 57    45   0       115   260      185      0.0       male
# 58    34   0       118   182      174      0.0       male
# 59    57   1       128   303      159      0.0     female
# 60    71   1       110   265      130      0.0     female
# 61    54   0       108   309      156      0.0       male
# 62    52   0       118   186      190      0.0       male
# 63    41   0       135   203      132      0.0       male
# 64    58   0       140   211      165      0.0       male
# 65    35   0       138   183      182      1.4     female
# 66    51   0       100   222      143      1.2       male
# 67    45   0       130   234      175      0.6     female
# 68    44   0       120   220      170      0.0       male
# 69    62   0       124   209      163      0.0     female
# 70    54   0       120   258      147      0.4       male
# 71    51   1        94   227      154      0.0       male
# 72    29   0       130   204      202      0.0       male
# 73    51   0       140   261      186      0.0       male
# 74    43   0       122   213      165      0.2     female
# 75    55   0       135   250      161      1.4     female
# 76    51   0       125   245      166      2.4       male
# 77    59   0       140   221      164      0.0       male
# 78    52   0       128   205      184      0.0       male
# 79    58   0       105   240      154      0.6       male
# 80    41   0       112   250      179      0.0       male
# 81    45   0       128   308      170      0.0       male
# 82    60   1       102   318      160      0.0     female
# 83    52   0       152   298      178      1.2       male
# 84    42   0       102   265      122      0.6     female
# 85    67   0       115   564      160      1.6     female
# 86    68   1       118   277      151      1.0       male
# 87    46   0       101   197      156      0.0       male
# 88    54   0       110   214      158      1.6     female
# 89    58   0       100   248      122      1.0     female
# 90    48   2       124   255      175      0.0       male
# 91    57   0       132   207      168      0.0       male
# 92    52   0       138   223      169      0.0       male
# 93    54   1       132   288      159      0.0     female
# 94    45   0       112   160      138      0.0     female
# 95    53   0       142   226      111      0.0       male
# 96    62   0       140   394      157      1.2     female
# 97    52   3       108   233      147      0.1       male
# 98    43   1       130   315      162      1.9       male
# 99    53   3       130   246      173      0.0       male
# 100   42   2       148   244      178      0.8       male
# 101   59   0       178   270      145      4.2       male
# 102   63   2       140   195      179      0.0     female
# 103   42   0       120   240      194      0.8       male
# 104   50   0       129   196      163      0.0       male
# 105   68   0       120   211      115      1.5     female
# 106   69   1       160   234      131      0.1       male
# 107   45   0       138   236      152      0.2     female
# 108   50   0       120   244      162      1.1     female
# 109   50   0       110   254      159      0.0     female
# 110   64   0       180   325      154      0.0     female
# 111   57   1       150   126      173      0.2       male
# 112   64   0       140   313      133      0.2     female
# 113   43   0       110   211      161      0.0       male
# 114   55   0       130   262      155      0.0       male
# 115   37   0       120   215      170      0.0     female
# 116   41   0       130   214      168      2.0       male
# 117   56   0       120   193      162      1.9       male
# 118   46   0       105   204      172      0.0     female
# 119   46   0       138   243      152      0.0     female
# 120   64   2       130   303      122      2.0     female
# 121   59   0       138   271      182      0.0       male
# 122   41   0       112   268      172      0.0     female
# 123   54   0       108   267      167      0.0     female
# 124   39   0        94   199      179      0.0     female
# 125   34   0       118   210      192      0.7     female
# 126   47   0       112   204      143      0.1       male
# 127   67   1       152   277      172      0.0     female
# 128   52   0       136   196      169      0.1     female
# 129   74   1       120   269      121      0.2     female
# 130   54   1       160   201      163      0.0     female
# 131   49   0       134   271      162      0.0     female
# 132   42   0       120   295      162      0.0       male
# 133   41   0       110   235      153      0.0       male
# 134   41   0       126   306      163      0.0     female
# 135   49   0       130   269      163      0.0     female
# 136   60   0       120   178       96      0.0     female
# 137   62   0       128   208      140      0.0       male
# 138   57   0       110   201      126      1.5       male
# 139   64   1       128   263      105      0.2       male
# 140   51   0       120   295      157      0.6     female
# 141   43   0       115   303      181      1.2       male
# 142   42   0       120   209      173      0.0     female
# 143   67   2       106   223      142      0.3     female
# 144   76   0       140   197      116      1.1     female
# 145   70   0       156   245      143      0.0       male
# 146   44   1       118   242      149      0.3     female
# 147   60   0       150   240      171      0.9     female
# 148   44   0       120   226      169      0.0       male
# 149   42   0       130   180      150      0.0       male
# 150   66   0       160   228      138      2.3       male
# 151   71   0       112   149      125      1.6     female
# 152   64   0       170   227      155      0.6       male
# 153   66   1       146   278      152      0.0     female
# 154   39   0       138   220      152      0.0     female
# 155   58   0       130   197      131      0.6     female
# 156   47   0       130   253      179      0.0       male
# 157   35   0       122   192      174      0.0       male
# 158   58   0       125   220      144      0.4       male
# 159   56   0       130   221      163      0.0       male
# 160   56   0       120   240      169      0.0       male
# 161   55   0       132   342      166      1.2     female
# 162   41   0       120   157      182      0.0       male
# 163   38   0       138   175      173      0.0       male
# 164   38   0       138   175      173      0.0       male
# 165   67   3       160   286      108      1.5       male
# 166   67   2       120   229      129      2.6       male
# 167   62   2       140   268      160      3.6     female
# 168   63   1       130   254      147      1.4       male
# 169   53   0       140   203      155      3.1       male
# 170   56   1       130   256      142      0.6       male
# 171   48   0       110   229      168      1.0       male
# 172   58   0       120   284      160      1.8       male
# 173   58   2       132   224      173      3.2       male
# 174   60   2       130   206      132      2.4       male
# 175   40   0       110   167      114      2.0       male
# 176   60   2       117   230      160      1.4       male
# 177   64   0       140   335      158      0.0       male
# 178   43   0       120   177      120      2.5       male
# 179   57   1       150   276      112      0.6       male
# 180   55   1       132   353      132      1.2       male
# 181   65   3       150   225      114      1.0     female
# 182   61   0       130   330      169      0.0     female
# 183   58   1       112   230      165      2.5       male
# 184   50   0       150   243      128      2.6       male
# 185   44   1       112   290      153      0.0       male
# 186   60   1       130   253      144      1.4       male
# 187   54   1       124   266      109      2.2       male
# 188   50   1       140   233      163      0.6       male
# 189   41   0       110   172      158      0.0       male
# 190   51   0       130   305      142      1.2     female
# 191   58   3       128   216      131      2.2       male
# 192   54   1       120   188      113      1.4       male
# 193   60   2       145   282      142      2.8       male
# 194   60   0       140   185      155      3.0       male
# 195   59   0       170   326      140      3.4       male
# 196   46   0       150   231      147      3.6       male
# 197   67   2       125   254      163      0.2       male
# 198   62   2       120   267       99      1.8       male
# 199   65   2       110   248      158      0.6       male
# 200   44   1       110   197      177      0.0       male
# 201   60   1       125   258      141      2.8       male
# 202   58   0       150   270      111      0.8       male
# 203   68   0       180   274      150      1.6       male
# 204   62   3       160   164      145      6.2     female
# 205   52   1       128   255      161      0.0       male
# 206   59   1       110   239      142      1.2       male
# 207   60   2       150   258      157      2.6     female
# 208   49   3       120   188      139      2.0       male
# 209   59   1       140   177      162      0.0       male
# 210   57   1       128   229      150      0.4       male
# 211   61   1       120   260      140      3.6       male
# 212   39   0       118   219      140      1.2       male
# 213   61   0       145   307      146      1.0     female
# 214   56   1       125   249      144      1.2       male
# 215   43   0       132   341      136      3.0     female
# 216   62   1       130   263       97      1.2     female
# 217   63   3       130   330      132      1.8       male
# 218   65   1       135   254      127      2.8       male
# 219   48   2       130   256      150      0.0       male
# 220   63   3       150   407      154      4.0     female
# 221   55   0       140   217      111      5.6       male
# 222   65   1       138   282      174      1.4       male
# 223   56   2       200   288      133      4.0     female
# 224   54   1       110   239      126      2.8       male
# 225   70   0       145   174      125      2.6       male
# 226   62   1       120   281      103      1.4       male
# 227   35   0       120   198      130      1.6       male
# 228   59   0       170   288      159      0.2       male
# 229   64   0       125   309      131      1.8       male
# 230   47   0       108   243      152      0.0       male
# 231   57   3       165   289      124      1.0       male
# 232   55   1       160   289      145      0.8       male
# 233   64   1       120   246       96      2.2       male
# 234   70   3       130   322      109      2.4       male
# 235   51   0       140   299      173      1.6       male
# 236   58   2       125   300      171      0.0       male
# 237   60   2       140   293      170      1.2       male
# 238   77   3       125   304      162      0.0       male
# 239   35   0       126   282      156      0.0       male
# 240   70   1       160   269      112      2.9       male
# 241   59   0       174   249      143      0.0     female
# 242   64   2       145   212      132      2.0       male
# 243   57   1       152   274       88      1.2       male
# 244   56   1       132   184      105      2.1       male
# 245   48   0       124   274      166      0.5       male
# 246   56   2       134   409      150      1.9     female
# 247   66   3       160   246      120      0.0       male
# 248   54   1       192   283      195      0.0       male
# 249   69   3       140   254      146      2.0       male
# 250   51   3       140   298      122      4.2       male
# 251   43   0       132   247      143      0.1       male
# 252   62   3       138   294      106      1.9     female
# 253   67   2       100   299      125      0.9       male
# 254   59   0       160   273      125      0.0       male
# 255   45   3       142   309      147      0.0       male
# 256   58   2       128   259      130      3.0       male
# 257   50   0       144   200      126      0.9       male
# 258   62   0       150   244      154      1.4     female
# 259   38   0       120   231      182      3.8       male
# 260   66   2       178   228      165      1.0     female
# 261   52   1       112   230      160      0.0       male
# 262   53   2       123   282       95      2.0       male
# 263   63   2       108   269      169      1.8     female
# 264   54   1       110   206      108      0.0       male
# 265   66   1       112   212      132      0.1       male
# 266   55   0       180   327      117      3.4     female
# 267   49   3       118   149      126      0.8       male
# 268   54   2       122   286      116      3.2       male
# 269   56   0       130   283      103      1.6       male
# 270   46   0       120   249      144      0.8       male
# 271   61   2       134   234      145      2.6       male
# 272   67   0       120   237       71      1.0       male
# 273   58   1       100   234      156      0.1       male
# 274   47   1       110   275      118      1.0       male
# 275   52   2       125   212      168      1.0       male
# 276   58   1       146   218      105      2.0       male
# 277   57   0       124   261      141      0.3       male
# 278   58   2       136   319      152      0.0     female
# 279   61   1       138   166      125      3.6       male
# 280   42   0       136   315      125      1.8       male
# 281   52   0       128   204      156      1.0       male
# 282   59   1       126   218      134      2.2       male
# 283   40   0       152   223      181      0.0       male
# 284   61   1       140   207      138      1.9       male
# 285   46   2       140   311      120      1.8       male
# 286   59   2       134   204      162      0.8       male
# 287   57   1       154   232      164      0.0       male
# 288   57   1       110   335      143      3.0       male
# 289   55   1       128   205      130      2.0     female
# 290   61   1       148   203      161      0.0       male
# 291   58   3       114   318      140      4.4       male
# 292   58   2       170   225      146      2.8     female
# 293   67   0       152   212      150      0.8       male
# 294   44   0       120   169      144      2.8       male
# 295   63   2       140   187      144      4.0       male
# 296   63   0       124   197      136      0.0     female
# 297   59   2       164   176       90      1.0       male
# 298   57   0       140   241      123      0.2     female
# 299   45   0       110   264      132      1.2       male
# 300   68   2       144   193      141      3.4       male
# 301   57   1       130   131      115      1.2       male
# 302   57   1       130   236      174      0.0     female
#
#                CP_string                RESTECG_string EXANG_string  \
# 0    asymptomatic angina                        normal           no
# 1             non-angina         ST-T wave abnormality           no
# 2        atypical angina                        normal           no
# 3        atypical angina         ST-T wave abnormality           no
# 4         typical angina         ST-T wave abnormality          yes
# 5         typical angina         ST-T wave abnormality           no
# 6        atypical angina                        normal           no
# 7        atypical angina         ST-T wave abnormality           no
# 8             non-angina         ST-T wave abnormality           no
# 9             non-angina         ST-T wave abnormality           no
# 10        typical angina         ST-T wave abnormality           no
# 11            non-angina         ST-T wave abnormality           no
# 12       atypical angina         ST-T wave abnormality           no
# 13   asymptomatic angina                        normal          yes
# 14   asymptomatic angina                        normal           no
# 15            non-angina         ST-T wave abnormality           no
# 16            non-angina         ST-T wave abnormality           no
# 17   asymptomatic angina         ST-T wave abnormality           no
# 18        typical angina         ST-T wave abnormality           no
# 19   asymptomatic angina         ST-T wave abnormality           no
# 20        typical angina         ST-T wave abnormality           no
# 21            non-angina         ST-T wave abnormality          yes
# 22        typical angina         ST-T wave abnormality           no
# 23            non-angina         ST-T wave abnormality          yes
# 24   asymptomatic angina         ST-T wave abnormality          yes
# 25       atypical angina         ST-T wave abnormality           no
# 26            non-angina         ST-T wave abnormality           no
# 27            non-angina         ST-T wave abnormality           no
# 28            non-angina                        normal           no
# 29            non-angina                        normal           no
# 30       atypical angina         ST-T wave abnormality           no
# 31        typical angina         ST-T wave abnormality           no
# 32       atypical angina                        normal           no
# 33            non-angina                        normal           no
# 34   asymptomatic angina                        normal          yes
# 35            non-angina                        normal          yes
# 36            non-angina         ST-T wave abnormality           no
# 37            non-angina                        normal           no
# 38            non-angina         ST-T wave abnormality           no
# 39            non-angina                        normal           no
# 40            non-angina                        normal           no
# 41       atypical angina                        normal           no
# 42        typical angina                        normal          yes
# 43        typical angina                        normal           no
# 44            non-angina                        normal           no
# 45       atypical angina         ST-T wave abnormality           no
# 46            non-angina                        normal           no
# 47            non-angina                        normal           no
# 48            non-angina                        normal           no
# 49        typical angina                        normal           no
# 50            non-angina                        normal           no
# 51        typical angina                        normal           no
# 52            non-angina         ST-T wave abnormality           no
# 53            non-angina         ST-T wave abnormality           no
# 54            non-angina                        normal           no
# 55       atypical angina         ST-T wave abnormality           no
# 56        typical angina                        normal           no
# 57        typical angina                        normal           no
# 58   asymptomatic angina                        normal           no
# 59        typical angina                        normal           no
# 60            non-angina                        normal           no
# 61       atypical angina         ST-T wave abnormality           no
# 62   asymptomatic angina                        normal           no
# 63       atypical angina         ST-T wave abnormality           no
# 64            non-angina                        normal           no
# 65        typical angina         ST-T wave abnormality           no
# 66            non-angina         ST-T wave abnormality          yes
# 67       atypical angina                        normal           no
# 68       atypical angina         ST-T wave abnormality           no
# 69        typical angina         ST-T wave abnormality           no
# 70            non-angina                        normal           no
# 71            non-angina         ST-T wave abnormality          yes
# 72       atypical angina                        normal           no
# 73        typical angina                        normal          yes
# 74            non-angina         ST-T wave abnormality           no
# 75       atypical angina                        normal           no
# 76            non-angina                        normal           no
# 77       atypical angina         ST-T wave abnormality          yes
# 78       atypical angina         ST-T wave abnormality           no
# 79            non-angina                        normal          yes
# 80            non-angina         ST-T wave abnormality           no
# 81       atypical angina                        normal           no
# 82            non-angina         ST-T wave abnormality           no
# 83   asymptomatic angina         ST-T wave abnormality           no
# 84        typical angina                        normal           no
# 85            non-angina                        normal           no
# 86            non-angina         ST-T wave abnormality           no
# 87       atypical angina         ST-T wave abnormality           no
# 88            non-angina         ST-T wave abnormality           no
# 89        typical angina                        normal           no
# 90            non-angina         ST-T wave abnormality           no
# 91        typical angina         ST-T wave abnormality          yes
# 92            non-angina         ST-T wave abnormality           no
# 93       atypical angina                        normal          yes
# 94       atypical angina         ST-T wave abnormality           no
# 95        typical angina                        normal          yes
# 96        typical angina                        normal           no
# 97        typical angina         ST-T wave abnormality           no
# 98            non-angina         ST-T wave abnormality           no
# 99            non-angina                        normal           no
# 100  asymptomatic angina                        normal           no
# 101  asymptomatic angina                        normal           no
# 102      atypical angina         ST-T wave abnormality           no
# 103           non-angina         ST-T wave abnormality           no
# 104           non-angina         ST-T wave abnormality           no
# 105           non-angina                        normal           no
# 106  asymptomatic angina                        normal           no
# 107       typical angina                        normal          yes
# 108      atypical angina         ST-T wave abnormality           no
# 109       typical angina                        normal           no
# 110       typical angina         ST-T wave abnormality          yes
# 111           non-angina         ST-T wave abnormality           no
# 112           non-angina         ST-T wave abnormality           no
# 113       typical angina         ST-T wave abnormality           no
# 114      atypical angina         ST-T wave abnormality           no
# 115           non-angina         ST-T wave abnormality           no
# 116           non-angina                        normal           no
# 117  asymptomatic angina                        normal           no
# 118      atypical angina         ST-T wave abnormality           no
# 119       typical angina                        normal          yes
# 120       typical angina         ST-T wave abnormality           no
# 121       typical angina                        normal           no
# 122           non-angina                        normal          yes
# 123           non-angina                        normal           no
# 124           non-angina         ST-T wave abnormality           no
# 125      atypical angina         ST-T wave abnormality           no
# 126       typical angina         ST-T wave abnormality           no
# 127           non-angina         ST-T wave abnormality           no
# 128           non-angina                        normal           no
# 129      atypical angina                        normal          yes
# 130           non-angina         ST-T wave abnormality           no
# 131      atypical angina         ST-T wave abnormality           no
# 132      atypical angina         ST-T wave abnormality           no
# 133      atypical angina         ST-T wave abnormality           no
# 134      atypical angina         ST-T wave abnormality           no
# 135       typical angina         ST-T wave abnormality           no
# 136           non-angina         ST-T wave abnormality           no
# 137      atypical angina                        normal           no
# 138       typical angina         ST-T wave abnormality          yes
# 139       typical angina         ST-T wave abnormality          yes
# 140           non-angina                        normal           no
# 141       typical angina         ST-T wave abnormality           no
# 142           non-angina         ST-T wave abnormality           no
# 143       typical angina         ST-T wave abnormality           no
# 144           non-angina  left ventricular hypertrophy           no
# 145      atypical angina                        normal           no
# 146           non-angina         ST-T wave abnormality           no
# 147  asymptomatic angina         ST-T wave abnormality           no
# 148           non-angina         ST-T wave abnormality           no
# 149           non-angina         ST-T wave abnormality           no
# 150       typical angina                        normal           no
# 151       typical angina         ST-T wave abnormality           no
# 152  asymptomatic angina                        normal           no
# 153           non-angina                        normal           no
# 154           non-angina         ST-T wave abnormality           no
# 155       typical angina         ST-T wave abnormality           no
# 156           non-angina         ST-T wave abnormality           no
# 157      atypical angina         ST-T wave abnormality           no
# 158      atypical angina         ST-T wave abnormality           no
# 159      atypical angina                        normal           no
# 160      atypical angina         ST-T wave abnormality           no
# 161      atypical angina         ST-T wave abnormality           no
# 162      atypical angina         ST-T wave abnormality           no
# 163           non-angina         ST-T wave abnormality           no
# 164           non-angina         ST-T wave abnormality           no
# 165       typical angina                        normal          yes
# 166       typical angina                        normal          yes
# 167       typical angina                        normal           no
# 168       typical angina                        normal           no
# 169       typical angina                        normal          yes
# 170           non-angina                        normal          yes
# 171      atypical angina         ST-T wave abnormality           no
# 172      atypical angina                        normal           no
# 173           non-angina                        normal           no
# 174       typical angina                        normal          yes
# 175       typical angina                        normal          yes
# 176       typical angina         ST-T wave abnormality          yes
# 177           non-angina         ST-T wave abnormality           no
# 178       typical angina                        normal          yes
# 179       typical angina                        normal          yes
# 180       typical angina         ST-T wave abnormality          yes
# 181       typical angina                        normal           no
# 182       typical angina                        normal           no
# 183           non-angina                        normal           no
# 184       typical angina                        normal           no
# 185       typical angina                        normal           no
# 186       typical angina         ST-T wave abnormality          yes
# 187       typical angina                        normal          yes
# 188           non-angina         ST-T wave abnormality           no
# 189       typical angina                        normal           no
# 190       typical angina         ST-T wave abnormality          yes
# 191       typical angina                        normal          yes
# 192       typical angina         ST-T wave abnormality           no
# 193       typical angina                        normal          yes
# 194           non-angina                        normal           no
# 195       typical angina                        normal          yes
# 196           non-angina         ST-T wave abnormality           no
# 197       typical angina         ST-T wave abnormality           no
# 198       typical angina         ST-T wave abnormality          yes
# 199       typical angina                        normal           no
# 200       typical angina                        normal           no
# 201       typical angina                        normal          yes
# 202       typical angina                        normal          yes
# 203           non-angina                        normal          yes
# 204       typical angina                        normal           no
# 205       typical angina         ST-T wave abnormality          yes
# 206       typical angina                        normal          yes
# 207       typical angina                        normal           no
# 208           non-angina         ST-T wave abnormality           no
# 209       typical angina         ST-T wave abnormality          yes
# 210           non-angina                        normal           no
# 211       typical angina         ST-T wave abnormality          yes
# 212       typical angina         ST-T wave abnormality           no
# 213       typical angina                        normal          yes
# 214       typical angina                        normal          yes
# 215       typical angina                        normal          yes
# 216           non-angina         ST-T wave abnormality           no
# 217       typical angina                        normal          yes
# 218       typical angina                        normal           no
# 219       typical angina                        normal          yes
# 220       typical angina                        normal           no
# 221       typical angina         ST-T wave abnormality          yes
# 222  asymptomatic angina                        normal           no
# 223       typical angina                        normal          yes
# 224       typical angina         ST-T wave abnormality          yes
# 225       typical angina         ST-T wave abnormality          yes
# 226      atypical angina                        normal           no
# 227       typical angina         ST-T wave abnormality          yes
# 228  asymptomatic angina                        normal           no
# 229           non-angina         ST-T wave abnormality          yes
# 230           non-angina         ST-T wave abnormality           no
# 231       typical angina                        normal           no
# 232       typical angina                        normal          yes
# 233       typical angina                        normal          yes
# 234       typical angina                        normal           no
# 235       typical angina         ST-T wave abnormality          yes
# 236       typical angina                        normal           no
# 237       typical angina                        normal           no
# 238       typical angina                        normal          yes
# 239       typical angina                        normal          yes
# 240           non-angina         ST-T wave abnormality          yes
# 241       typical angina         ST-T wave abnormality          yes
# 242       typical angina                        normal           no
# 243       typical angina         ST-T wave abnormality          yes
# 244       typical angina                        normal          yes
# 245       typical angina                        normal           no
# 246       typical angina                        normal          yes
# 247      atypical angina         ST-T wave abnormality          yes
# 248      atypical angina                        normal           no
# 249           non-angina                        normal           no
# 250       typical angina         ST-T wave abnormality          yes
# 251       typical angina                        normal          yes
# 252       typical angina         ST-T wave abnormality           no
# 253       typical angina                        normal          yes
# 254  asymptomatic angina                        normal           no
# 255       typical angina                        normal          yes
# 256       typical angina                        normal          yes
# 257       typical angina                        normal          yes
# 258       typical angina         ST-T wave abnormality          yes
# 259  asymptomatic angina         ST-T wave abnormality          yes
# 260       typical angina         ST-T wave abnormality          yes
# 261       typical angina         ST-T wave abnormality           no
# 262       typical angina         ST-T wave abnormality          yes
# 263       typical angina         ST-T wave abnormality          yes
# 264       typical angina                        normal          yes
# 265       typical angina                        normal          yes
# 266       typical angina  left ventricular hypertrophy          yes
# 267           non-angina                        normal           no
# 268       typical angina                        normal          yes
# 269       typical angina                        normal          yes
# 270       typical angina                        normal           no
# 271  asymptomatic angina         ST-T wave abnormality           no
# 272       typical angina         ST-T wave abnormality           no
# 273       typical angina         ST-T wave abnormality           no
# 274       typical angina                        normal          yes
# 275       typical angina         ST-T wave abnormality           no
# 276       typical angina         ST-T wave abnormality           no
# 277      atypical angina         ST-T wave abnormality           no
# 278      atypical angina                        normal           no
# 279       typical angina                        normal          yes
# 280       typical angina         ST-T wave abnormality          yes
# 281       typical angina         ST-T wave abnormality          yes
# 282           non-angina         ST-T wave abnormality           no
# 283       typical angina         ST-T wave abnormality           no
# 284       typical angina                        normal          yes
# 285       typical angina         ST-T wave abnormality          yes
# 286  asymptomatic angina         ST-T wave abnormality           no
# 287      atypical angina                        normal           no
# 288       typical angina         ST-T wave abnormality          yes
# 289       typical angina  left ventricular hypertrophy          yes
# 290       typical angina         ST-T wave abnormality           no
# 291       typical angina  left ventricular hypertrophy           no
# 292       typical angina                        normal          yes
# 293           non-angina                        normal           no
# 294       typical angina         ST-T wave abnormality          yes
# 295       typical angina                        normal          yes
# 296       typical angina         ST-T wave abnormality          yes
# 297       typical angina                        normal           no
# 298       typical angina         ST-T wave abnormality          yes
# 299  asymptomatic angina         ST-T wave abnormality           no
# 300       typical angina         ST-T wave abnormality           no
# 301       typical angina         ST-T wave abnormality          yes
# 302      atypical angina                        normal           no
#
#     FBS_string        THAL_string  TARGET_string Race_String  incident  \
# 0         HIGH             normal   asymptomatic       white     3.803
# 1          low       fixed defect   asymptomatic       black     2.815
# 2          low       fixed defect   asymptomatic       white     1.854
# 3          low       fixed defect   asymptomatic       black    23.172
# 4          low       fixed defect   asymptomatic       white    13.378
# 5          low             normal   asymptomatic       black     6.235
# 6          low       fixed defect   asymptomatic       white     2.263
# 7          low  reversable defect   asymptomatic       white    36.234
# 8         HIGH  reversable defect   asymptomatic       asian     2.312
# 9          low       fixed defect   asymptomatic       asian     3.670
# 10         low       fixed defect   asymptomatic       asian     0.502
# 11         low       fixed defect   asymptomatic       black     5.262
# 12         low       fixed defect   asymptomatic       asian     1.470
# 13         low       fixed defect   asymptomatic       asian    23.084
# 14        HIGH       fixed defect   asymptomatic       black     1.395
# 15         low       fixed defect   asymptomatic       black     1.986
# 16         low       fixed defect   asymptomatic       asian     1.817
# 17         low       fixed defect   asymptomatic       white     7.887
# 18         low       fixed defect   asymptomatic       asian     3.305
# 19         low       fixed defect   asymptomatic       black     3.403
# 20         low  reversable defect   asymptomatic       black     2.432
# 21         low       fixed defect   asymptomatic       asian     2.644
# 22         low       fixed defect   asymptomatic       asian     1.078
# 23        HIGH       fixed defect   asymptomatic       asian     1.149
# 24         low  reversable defect   asymptomatic       white     1.008
# 25         low       fixed defect   asymptomatic       asian     0.540
# 26        HIGH       fixed defect   asymptomatic       black     2.934
# 27         low       fixed defect   asymptomatic       black     0.487
# 28        HIGH       fixed defect   asymptomatic       black     1.712
# 29        HIGH       fixed defect   asymptomatic       asian     1.686
# 30         low       fixed defect   asymptomatic       black     6.972
# 31         low  reversable defect   asymptomatic       asian     1.979
# 32         low       fixed defect   asymptomatic       black     1.575
# 33         low       fixed defect   asymptomatic       black     0.368
# 34         low       fixed defect   asymptomatic       black     1.143
# 35         low       fixed defect   asymptomatic       white     1.672
# 36        HIGH       fixed defect   asymptomatic       black    19.394
# 37         low  reversable defect   asymptomatic       black    19.776
# 38         low       fixed defect   asymptomatic       black     3.761
# 39         low       fixed defect   asymptomatic       asian     2.148
# 40         low       fixed defect   asymptomatic       black     3.035
# 41         low       fixed defect   asymptomatic       white     1.726
# 42         low       fixed defect   asymptomatic       asian     3.265
# 43         low       fixed defect   asymptomatic       asian     3.284
# 44         low       fixed defect   asymptomatic       white     2.704
# 45         low       fixed defect   asymptomatic       asian     2.167
# 46         low       fixed defect   asymptomatic       black     0.849
# 47         low       fixed defect   asymptomatic       white     1.346
# 48         low                NaN   asymptomatic       asian     3.265
# 49         low       fixed defect   asymptomatic       asian     3.808
# 50         low       fixed defect   asymptomatic       black     3.360
# 51         low       fixed defect   asymptomatic       black     2.172
# 52         low  reversable defect   asymptomatic       asian     2.075
# 53         low       fixed defect   asymptomatic       white     4.122
# 54         low       fixed defect   asymptomatic       black     4.173
# 55         low       fixed defect   asymptomatic       black     1.076
# 56         low       fixed defect   asymptomatic       black     5.528
# 57         low       fixed defect   asymptomatic       white     2.854
# 58         low       fixed defect   asymptomatic       white     0.718
# 59         low       fixed defect   asymptomatic       black     2.610
# 60        HIGH       fixed defect   asymptomatic       white     1.839
# 61         low  reversable defect   asymptomatic       asian    53.684
# 62         low             normal   asymptomatic       black     0.628
# 63         low             normal   asymptomatic       asian     2.007
# 64        HIGH       fixed defect   asymptomatic       white     2.393
# 65         low       fixed defect   asymptomatic       asian     0.762
# 66         low       fixed defect   asymptomatic       black     5.427
# 67         low       fixed defect   asymptomatic       black     0.522
# 68         low       fixed defect   asymptomatic       asian     1.807
# 69         low       fixed defect   asymptomatic       black    35.379
# 70         low  reversable defect   asymptomatic       black     1.988
# 71         low  reversable defect   asymptomatic       black     8.585
# 72         low       fixed defect   asymptomatic       black     1.778
# 73         low       fixed defect   asymptomatic       white     2.113
# 74         low       fixed defect   asymptomatic       asian     3.462
# 75         low       fixed defect   asymptomatic       asian     3.038
# 76        HIGH       fixed defect   asymptomatic       black     0.480
# 77         low       fixed defect   asymptomatic       asian     1.634
# 78        HIGH       fixed defect   asymptomatic       white     6.190
# 79         low  reversable defect   asymptomatic       black     5.174
# 80         low       fixed defect   asymptomatic       white     8.006
# 81         low       fixed defect   asymptomatic       asian    18.936
# 82         low       fixed defect   asymptomatic       asian     3.618
# 83        HIGH  reversable defect   asymptomatic       black     4.987
# 84         low       fixed defect   asymptomatic       asian     4.942
# 85         low  reversable defect   asymptomatic       asian    11.587
# 86         low  reversable defect   asymptomatic       asian     2.442
# 87        HIGH  reversable defect   asymptomatic       asian     2.918
# 88         low       fixed defect   asymptomatic       white     6.805
# 89         low       fixed defect   asymptomatic       white     4.618
# 90        HIGH       fixed defect   asymptomatic       black    13.855
# 91         low  reversable defect   asymptomatic       asian    10.624
# 92         low       fixed defect   asymptomatic       black     0.869
# 93        HIGH       fixed defect   asymptomatic       black    19.755
# 94         low       fixed defect   asymptomatic       white     1.530
# 95         low  reversable defect   asymptomatic       white    22.740
# 96         low       fixed defect   asymptomatic       asian     1.047
# 97        HIGH  reversable defect   asymptomatic       asian     0.943
# 98         low       fixed defect   asymptomatic       asian     5.760
# 99        HIGH       fixed defect   asymptomatic       black     1.415
# 100        low       fixed defect   asymptomatic       white     0.754
# 101        low  reversable defect   asymptomatic       black     0.622
# 102        low       fixed defect   asymptomatic       white     2.552
# 103       HIGH  reversable defect   asymptomatic       black     2.280
# 104        low       fixed defect   asymptomatic       white    15.947
# ...
# 190        low  reversable defect  heart disease       white     9.506
# 191        low  reversable defect  heart disease       white     1.585
# 192        low  reversable defect  heart disease       white     1.074
# 193        low  reversable defect  heart disease       white     2.341
# 194        low       fixed defect  heart disease       white     3.067
# 195        low  reversable defect  heart disease       white     1.986
# 196        low       fixed defect  heart disease       white    10.771
# 197       HIGH  reversable defect  heart disease       white     8.853
# 198        low  reversable defect  heart disease       white     3.392
# 199        low             normal  heart disease       white     4.341
# 200        low       fixed defect  heart disease       white     1.941
# 201        low  reversable defect  heart disease       white     1.590
# 202        low  reversable defect  heart disease       white     1.892
# 203       HIGH  reversable defect  heart disease       white     1.837
# 204        low  reversable defect  heart disease       white     2.178
# 205        low  reversable defect  heart disease       white     1.954
# 206        low  reversable defect  heart disease       white     0.523
# 207        low  reversable defect  heart disease       white     1.550
# 208        low  reversable defect  heart disease       white     2.620
# 209        low  reversable defect  heart disease       white     0.365
# 210        low  reversable defect  heart disease       white     4.480
# 211        low  reversable defect  heart disease       white     1.815
# 212        low  reversable defect  heart disease       white     4.174
# 213        low  reversable defect  heart disease       white     3.606
# 214       HIGH       fixed defect  heart disease       white     3.870
# 215       HIGH  reversable defect  heart disease       white     2.594
# 216        low  reversable defect  heart disease       white     0.919
# 217       HIGH  reversable defect  heart disease       white     4.022
# 218        low  reversable defect  heart disease       white     3.512
# 219       HIGH  reversable defect  heart disease       white    15.851
# 220        low  reversable defect  heart disease       white     4.315
# 221        low  reversable defect  heart disease       white    72.143
# 222       HIGH       fixed defect  heart disease       white     0.408
# 223       HIGH  reversable defect  heart disease       white     0.310
# 224        low  reversable defect  heart disease       white     0.887
# 225        low  reversable defect  heart disease       white     1.101
# 226        low  reversable defect  heart disease       white     0.747
# 227        low  reversable defect  heart disease       white     1.579
# 228        low  reversable defect  heart disease       white     0.791
# 229        low  reversable defect  heart disease       white     2.516
# 230        low       fixed defect  heart disease       white     0.338
# 231       HIGH  reversable defect  heart disease       white    85.169
# 232        low  reversable defect  heart disease       white     9.225
# 233        low       fixed defect  heart disease       white     1.739
# 234        low       fixed defect  heart disease       white     1.305
# 235        low  reversable defect  heart disease       white     1.734
# 236        low  reversable defect  heart disease       white     1.721
# 237        low  reversable defect  heart disease       white     2.195
# 238        low       fixed defect  heart disease       white     3.127
# 239        low  reversable defect  heart disease       white     1.625
# 240        low  reversable defect  heart disease       white     0.360
# 241        low       fixed defect  heart disease       white     3.081
# 242        low             normal  heart disease       white     1.275
# 243        low  reversable defect  heart disease       white     0.574
# 244        low             normal  heart disease       white     0.994
# 245        low  reversable defect  heart disease       white     1.327
# 246        low  reversable defect  heart disease       white    36.806
# 247        low             normal  heart disease       white     3.095
# 248        low  reversable defect  heart disease       white    20.187
# 249        low  reversable defect  heart disease       white    80.756
# 250        low  reversable defect  heart disease       white     3.141
# 251       HIGH  reversable defect  heart disease       white     4.016
# 252       HIGH       fixed defect  heart disease       white     8.774
# 253        low       fixed defect  heart disease       white     3.324
# 254        low       fixed defect  heart disease       white     1.618
# 255        low  reversable defect  heart disease       white     3.552
# 256        low  reversable defect  heart disease       white    13.821
# 257        low  reversable defect  heart disease       white     1.028
# 258        low       fixed defect  heart disease       white     3.576
# 259        low  reversable defect  heart disease       white    10.978
# 260       HIGH  reversable defect  heart disease       white     1.416
# 261        low       fixed defect  heart disease       white    55.703
# 262        low  reversable defect  heart disease       white     2.089
# 263        low       fixed defect  heart disease       white     2.050
# 264        low       fixed defect  heart disease       white     2.495
# 265        low       fixed defect  heart disease       white     1.562
# 266        low       fixed defect  heart disease       white     4.384
# 267        low       fixed defect  heart disease       white     2.183
# 268        low       fixed defect  heart disease       white     1.808
# 269       HIGH  reversable defect  heart disease       white     5.050
# 270        low  reversable defect  heart disease       white     4.760
# 271        low       fixed defect  heart disease       white     3.050
# 272        low       fixed defect  heart disease       white     2.983
# 273        low  reversable defect  heart disease       white     6.238
# 274        low       fixed defect  heart disease       white     0.792
# 275        low  reversable defect  heart disease       white     2.511
# 276        low  reversable defect  heart disease       white     0.922
# 277        low  reversable defect  heart disease       white     1.399
# 278       HIGH       fixed defect  heart disease       white     7.476
# 279        low       fixed defect  heart disease       white     1.080
# 280        low             normal  heart disease       white    15.499
# 281       HIGH                NaN  heart disease       white     1.156
# 282       HIGH             normal  heart disease       white     1.096
# 283        low  reversable defect  heart disease       white     3.104
# 284        low  reversable defect  heart disease       white     2.461
# 285        low  reversable defect  heart disease       white     0.730
# 286        low       fixed defect  heart disease       white     8.345
# 287        low       fixed defect  heart disease       white     0.986
# 288        low  reversable defect  heart disease       white     0.951
# 289        low  reversable defect  heart disease       white     7.976
# 290        low  reversable defect  heart disease       white     1.437
# 291        low             normal  heart disease       white     1.398
# 292       HIGH             normal  heart disease       white     1.966
# 293        low  reversable defect  heart disease       white     0.627
# 294        low             normal  heart disease       white     2.833
# 295        low  reversable defect  heart disease       white     2.144
# 296        low       fixed defect  heart disease       white     0.239
# 297       HIGH             normal  heart disease       white     4.409
# 298        low  reversable defect  heart disease       white     2.074
# 299        low  reversable defect  heart disease       white     1.935
# 300       HIGH  reversable defect  heart disease       white    36.971
# 301        low  reversable defect  heart disease       white     1.886
# 302        low       fixed defect  heart disease       white     5.109
#
#      ExterQual_numeric
# 0                    1
# 1                    1
# 2                   -1
# 3                   -1
# 4                   -1
# 5                    0
# 6                    0
# 7                   -1
# 8                   -1
# 9                   -1
# 10                  -1
# 11                  -1
# 12                  -1
# 13                   0
# 14                  -1
# 15                   0
# 16                  -1
# 17                   1
# 18                  -1
# 19                  -1
# 20                   0
# 21                  -1
# 22                  -1
# 23                   0
# 24                  -1
# 25                  -1
# 26                  -1
# 27                  -1
# 28                  -1
# 29                   1
# 30                  -1
# 31                  -1
# 32                  -1
# 33                   1
# 34                  -1
# 35                   1
# 36                  -1
# 37                  -1
# 38                  -1
# 39                  -1
# 40                  -1
# 41                   0
# 42                   0
# 43                   0
# 44                  -1
# 45                  -1
# 46                  -1
# 47                  -1
# 48                  -1
# 49                  -1
# 50                  -1
# 51                   0
# 52                   0
# 53                   0
# 54                  -1
# 55                  -1
# 56                  -1
# 57                  -1
# 58                  -1
# 59                  -1
# 60                  -1
# 61                  -1
# 62                   0
# 63                   0
# 64                  -1
# 65                  -1
# 66                   0
# 67                   0
# 68                  -1
# 69                  -1
# 70                   0
# 71                  -1
# 72                  -1
# 73                  -1
# 74                   0
# 75                   0
# 76                   0
# 77                  -1
# 78                  -1
# 79                   0
# 80                  -1
# 81                  -1
# 82                  -1
# 83                   0
# 84                   0
# 85                   0
# 86                  -1
# 87                  -1
# 88                   0
# 89                   0
# 90                  -1
# 91                  -1
# 92                  -1
# 93                  -1
# 94                   0
# 95                  -1
# 96                   0
# 97                  -1
# 98                  -1
# 99                  -1
# 100                 -1
# 101                  1
# 102                 -1
# 103                  1
# 104                 -1
# 105                  0
# 106                  0
# 107                  0
# 108                 -1
# 109                 -1
# 110                 -1
# 111                 -1
# 112                 -1
# 113                 -1
# 114                 -1
# 115                 -1
# 116                  0
# 117                  0
# 118                 -1
# 119                  0
# 120                  0
# 121                 -1
# 122                 -1
# 123                 -1
# 124                 -1
# 125                 -1
# 126                 -1
# 127                 -1
# 128                  0
# 129                 -1
# 130                 -1
# 131                  0
# 132                 -1
# 133                 -1
# 134                 -1
# 135                 -1
# 136                 -1
# 137                 -1
# 138                  0
# 139                  0
# 140                 -1
# 141                  0
# 142                  0
# 143                 -1
# 144                  0
# 145                 -1
# 146                  0
# 147                 -1
# 148                 -1
# 149                 -1
# 150                 -1
# 151                  0
# 152                  0
# 153                  0
# 154                  0
# 155                  0
# 156                 -1
# 157                 -1
# 158                  0
# 159                 -1
# 160                  1
# 161                 -1
# 162                 -1
# 163                 -1
# 164                 -1
# 165                  0
# 166                  0
# 167                  1
# 168                  0
# 169                  1
# 170                  0
# 171                  1
# 172                  0
# 173                 -1
# 174                  0
# 175                  0
# 176                 -1
# 177                 -1
# 178                  0
# 179                  0
# 180                  0
# 181                  0
# 182                 -1
# 183                  0
# 184                  0
# 185                 -1
# 186                 -1
# 187                  0
# 188                  0
# 189                 -1
# 190                  0
# 191                  0
# 192                  0
# 193                  0
# 194                  0
# 195                  1
# 196                  0
# 197                  0
# 198                  0
# 199                 -1
# 200                 -1
# 201                  0
# 202                 -1
# 203                  0
# 204                  1
# 205                 -1
# 206                  0
# 207                  0
# 208                  0
# 209                 -1
# 210                  0
# 211                  0
# 212                  0
# 213                  0
# 214                  0
# 215                  0
# 216                  0
# 217                 -1
# 218                  0
# 219                 -1
# 220                  0
# 221                  1
# 222                  0
# 223                  1
# 224                  0
# 225                  1
# 226                  0
# 227                  0
# 228                  0
# 229                  0
# 230                 -1
# 231                  0
# 232                  0
# 233                  1
# 234                  0
# 235                 -1
# 236                 -1
# 237                  0
# 238                 -1
# 239                 -1
# 240                  0
# 241                  0
# 242                  0
# 243                  0
# 244                  0
# 245                  0
# 246                  0
# 247                  0
# 248                 -1
# 249                  0
# 250                  0
# 251                  0
# 252                  0
# 253                  0
# 254                 -1
# 255                  0
# 256                  0
# 257                  0
# 258                  0
# 259                  0
# 260                  0
# 261                 -1
# 262                  0
# 263                  0
# 264                  0
# 265                 -1
# 266                  0
# 267                 -1
# 268                  0
# 269                  1
# 270                 -1
# 271                  0
# 272                  0
# 273                 -1
# 274                  0
# 275                 -1
# 276                  0
# 277                 -1
# 278                 -1
# 279                  0
# 280                  0
# 281                  0
# 282                  0
# 283                 -1
# 284                 -1
# 285                  0
# 286                 -1
# 287                 -1
# 288                  0
# 289                  0
# 290                 -1
# 291                  1
# 292                  0
# 293                  0
# 294                  1
# 295                 -1
# 296                  0
# 297                  0
# 298                  0
# 299                  0
# 300                  0
# 301                  0
# 302                  0

# %%
# It is possible to make new variables with math, this is called "feature engineering"
# in this case, I will make a new variable by dividing one variable by another.
# because there could be multiple dataframes with the same variable name, I must
# identifiy the df AND the variable name in brackets and quotes.

# In python, the equal sign is used to assinge a variable, in this case "risk".
df["risk"] = (df["thalach"] + df["chol"])
# These variables are unique to the example dataset in "Heart_Synthetic.csv", update, move, or delete this cell or it will error because
# the variables are not in the new dataset (i.e., dataframe or df)

# %%
# Review the results of the new variable.
df["risk"].describe()
# This variable is unique to the example dataset in "Heart_Synthetic.csv", update, move, or delete this cell or it will error because
# the variables are not in the new dataset (i.e., dataframe or df)
# Out:
# count    303.000000
# mean     395.910891
# std       56.457702
# min      246.000000
# 25%      364.000000
# 50%      393.000000
# 75%      428.500000
# max      724.000000
# Name: risk, dtype: float64

# %% [markdown]
# ## EDA with Visualizations: matplotlib

# %% [markdown]
# ✅ Humans are very visual. We can often see patterns in data visualizations that we would not see in descriptive statestics tables or looking at the raw data.

# %%
# MatPlotLib is a common visulaization package.
# note that just pyplot is added in, not the full package
from matplotlib import pyplot as plt
#It is a function that renders the figure in a notebook (instead of displaying a dump of the figure object).
# %matplotlib inline

# %%
# We can build historgram plots for variables one by one using matplotlib
df.hist('risk')
df.hist('trestbps')
# But this can be vary tidious.
# These variables are unique to the example dataset in "Heart_Synthetic.csv".
# To update this code for other datasets, the variable names must be udpated.
# if you load data, you must move, or delete this cell or it will error because
# the variables are not in the new dataset (i.e., dataframe or df)
# Out:
# array([[<Axes: title={'center': 'trestbps'}>]], dtype=object)

# %%
## WE can use python to build all the appropriate histograms.
# prompt: build histograms for all numerical values in df

# Iterate over numerical columns and create histograms
for col in df.select_dtypes(include=np.number):
  plt.figure()  # Create a new figure for each histogram
  plt.hist(df[col], bins=10)  # Adjust the number of bins as needed
  plt.title(f'Histogram of {col}')
  plt.xlabel(col)
  plt.ylabel('Frequency')
  plt.show()

# %%
# The histograms did not look right with gaps in the x axis so I updated the prompt
# prompt: build a histogram for all numerical variables in the df. set the number of bins to the number of unique values in the variable
"""
import pandas as pd # Gemini will include the packages you need even though you already imported these in the first code cell.
from matplotlib import pyplot as plt
from matplotlib import pyplot as plt
"""

# Assuming 'df' is already loaded as in your provided code

for col in df.select_dtypes(include=['number']):
  num_unique = df[col].nunique()
  plt.figure(figsize=(8, 6))
  plt.hist(df[col], bins=num_unique)
  plt.title(f'Histogram of {col}')
  plt.xlabel(col)
  plt.ylabel('Frequency')
  plt.show()

# %% [markdown]
# ## EDA with Visualizations: seaborn

# %% [markdown]
# ✅ *Seaborn* is a great open-sourse tool and generally more user-friendly than *matplotlip*.

# %%
# need the seaborn library loaded.
import seaborn as sns

# %%
#build the same histogram with seaborn library
#you have lots of options
sns.histplot(data=df, x='risk')
# This variable is unique to the example dataset in "Heart_Synthetic.csv", update, move, or delete this cell or it will error because
# the variables are not in the new dataset (i.e., dataframe or df)
# Out:
# <Axes: xlabel='risk', ylabel='Count'>

# %%
# https://seaborn.pydata.org/generated/seaborn.catplot.html
sns.catplot(data=df, x="THAL_string", y="risk")
# This variable is unique to the example dataset in "Heart_Synthetic.csv", update, move, or delete this cell or it will error because
# the variable is not in the new dataset (i.e., dataframe or df)

# %%
#same data, but with a violin plot
#https://seaborn.pydata.org/generated/seaborn.violinplot.html#seaborn.violinplot
sns.violinplot(data=df, x="THAL_string", y="risk")
# Out:
# <Axes: xlabel='THAL_string', ylabel='risk'>

# %%
#swarm Plot
#https://seaborn.pydata.org/generated/seaborn.swarmplot.html#seaborn.swarmplot
sns.catplot(data=df, x="THAL_string", y="risk", hue="SEX_string", kind="swarm")

# %%
#Box & Whisker
#https://seaborn.pydata.org/generated/seaborn.boxplot.html#seaborn.boxplot
sns.boxplot(data=df, x="THAL_string", y="risk", hue="SEX_string")
# Out:
# <Axes: xlabel='THAL_string', ylabel='risk'>

# %%
# prompt: insert sns correlation matrix for all the numerical variables

# Correlation Matrix
# https://seaborn.pydata.org/generated/seaborn.heatmap.html
correlation_matrix = df.select_dtypes(include=np.number).corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
# prompt: Build a loop to identify all numerical values in the df and then perform a boxplot and a histogram. Be sure to label each plot.

# Loop through columns to identify numerical features
for col in df.columns:
  if pd.api.types.is_numeric_dtype(df[col]):
    # Create a boxplot
    plt.figure(figsize=(8, 6))  # Adjust figure size as needed
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')
    plt.xlabel(col)
    plt.show()

    # Create a histogram
    plt.figure(figsize=(8, 6))  # Adjust figure size as needed
    sns.histplot(df[col])
    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    plt.show()

# %% [markdown]
# ## EDA with Visualizations: plotly

# %% [markdown]
# ✅ *Plotly* is just another visualization library that provides other options.

# %%
#https://plotly.com/python/plotly-express/
import plotly.express as px

# %%
#Look at the Dependent Variable as it relates to these categorical variables
#consider this type of side-by-side box and whisker

px.box(data_frame=df,x='SEX_string', y='incident')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9e2ed385-e2e5-4112-ac8a-e83534181948" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9e2ed385-e2e5-4112-ac8a-e83534181948")) {                    Plotly.newPlot(                        "9e2ed385-e2e5-4112-ac8a-e83534181948",                        [{"alignmentgroup":"True","hovertemplate":"SEX_string=%{x}\u003cbr\u003eincident=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["male","male","female","male","female","male","female","male","male","male","male","female","male","male","female","female","female","female","male","female","male","male","male","male","male","female","male","male","female","male","female","male","male","male","male","female","female","male","female","female","female","male","male","female","male","male","male","male","female","female","female","male","male","female","female","male","male","male","male","female","female","male","male","male","male","female","male","female","male","female","male","male","male","male","female","female","male","male","male","male","male","male","female","male","female","female","male","male","female","female","male","male","male","female","female","male","female","male","male","male","male","male","female","male","male","female","male","female","female","female","female","male","female","male","male","female","male","male","female","female","female","male","female","female","female","female","male","female","female","female","female","female","male","male","female","female","female","male","male","male","female","male","female","female","female","male","female","female","male","male","male","female","male","female","female","female","male","male","male","male","male","female","male","male","male","male","male","female","male","male","male","male","male","male","male","male","male","male","male","male","male","female","female","male","male","male","male","male","male","male","female","male","male","male","male","male","male","male","male","male","male","male","male","male","female","male","male","female","male","male","male","male","male","female","male","female","female","male","male","male","female","male","male","female","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","male","female","male","male","male","male","female","male","male","male","male","male","female","male","male","male","male","male","female","male","female","male","male","female","male","male","female","male","male","male","male","male","male","male","male","male","male","male","female","male","male","male","male","male","male","male","male","male","male","female","male","male","female","male","male","male","female","male","female","male","male","male","female"],"x0":" ","xaxis":"x","y":[3.803,2.815,1.854,23.172,13.378,6.235,2.263,36.234,2.312,3.67,0.502,5.262,1.47,23.084,1.395,1.986,1.817,7.887,3.305,3.403,2.432,2.644,1.078,1.149,1.008,0.54,2.934,0.487,1.712,1.686,6.972,1.979,1.575,0.368,1.143,1.672,19.394,19.776,3.761,2.148,3.035,1.726,3.265,3.284,2.704,2.167,0.849,1.346,3.265,3.808,3.36,2.172,2.075,4.122,4.173,1.076,5.528,2.854,0.718,2.61,1.839,53.684,0.628,2.007,2.393,0.762,5.427,0.522,1.807,35.379,1.988,8.585,1.778,2.113,3.462,3.038,0.48,1.634,6.19,5.174,8.006,18.936,3.618,4.987,4.942,11.587,2.442,2.918,6.805,4.618,13.855,10.624,0.869,19.755,1.53,22.74,1.047,0.943,5.76,1.415,0.754,0.622,2.552,2.28,15.947,3.524,0.556,1.69,4.041,6.18,1.593,0.355,7.607,1.226,4.199,1.915,0.76,0.824,7.628,1.395,1.911,1.502,3.333,37.262,2.08,0.915,0.745,4.42,1.588,1.05,1.526,7.936,3.826,17.139,1.604,3.197,2.908,12.287,3.557,6.25 ...

# %%
px.box(data_frame=df,x='Race_String', y='incident')
# does the plot show outliers????
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2167f6d0-f06b-4cbb-a4d3-7360d074b72d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2167f6d0-f06b-4cbb-a4d3-7360d074b72d")) {                    Plotly.newPlot(                        "2167f6d0-f06b-4cbb-a4d3-7360d074b72d",                        [{"alignmentgroup":"True","hovertemplate":"Race_String=%{x}\u003cbr\u003eincident=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["white","black","white","black","white","black","white","white","asian","asian","asian","black","asian","asian","black","black","asian","white","asian","black","black","asian","asian","asian","white","asian","black","black","black","asian","black","asian","black","black","black","white","black","black","black","asian","black","white","asian","asian","white","asian","black","white","asian","asian","black","black","asian","white","black","black","black","white","white","black","white","asian","black","asian","white","asian","black","black","asian","black","black","black","black","white","asian","asian","black","asian","white","black","white","asian","asian","black","asian","asian","asian","asian","white","white","black","asian","black","black","white","white","asian","asian","asian","black","white","black","white","black","white","black","black","white","white","black","white","black","asian","black","black","black","white","asian","white","black","asian","black","white","asian","white","white","black","black","asian","asian","black","white","white","black","white","black","black","black","black","black","white","white","black","asian","asian","white","black","black","black","black","white","asian","asian","black","white","white","asian","white","black","white","black","black","asian","black","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white"],"x0":" ","xaxis":"x","y":[3.803,2.815,1.854,23.172,13.378,6.235,2.263,36.234,2.312,3.67,0.502,5.262,1.47,23.084,1.395,1.986,1.817,7.887,3.305,3.403,2.432,2.644,1.078,1.149,1.008,0.54,2.934,0.487,1.712,1.686,6.972,1.979,1.575,0.368,1.143,1.672,19.394,19.776,3.761,2.148,3.035,1.726,3.265,3.284,2.704,2.167,0.849,1.346,3.265,3.808,3.36,2.172,2.075,4.122,4.173,1.076,5.528,2.854,0.718,2.61,1.839,53.684,0.628,2.007,2.393,0.762,5.427,0.522,1.807,35.379,1.988,8.585,1.778,2.113,3.462,3.038,0.48,1.634,6.19,5.174,8.006,18.936,3.618,4.987,4.942,11.587,2.442,2.918,6.805,4.618,13.855,10.624,0.869,19.755,1.53,22.74,1.047,0.943,5.76,1.415,0.754,0.622,2.552,2.28,15.947,3.524,0.556,1.69,4.041,6.18,1.593,0.355,7.607,1.226,4.199,1.915,0.76,0.824,7.628,1.395,1.911, ...

# %% [markdown]
# ## EDA with query() in Pandas

# %% [markdown]
# ✅ Queries allow for deeper data investivgation as part of your EDA.

# %%
# VERY IMPORTANT
# Column names can not have spaces for Pandas Querry
# This code cell is important to run even though you think your varaibles names already have the spaces removed.

# Use print function to output and assess the old column names
print("Old Names: \n",  df.dtypes)

# replace the spaces with underscores
df.columns=[x.replace(" ", "_") for x in df.columns]

# Use print function to output and assess the new column names:
print("New Column names:\n", df.dtypes) #look at new column names
# Out:
# Old Names:
#  age                    int64
# ca                     int64
# trestbps               int64
# chol                   int64
# thalach                int64
# oldpeak              float64
# SEX_string            object
# CP_string             object
# RESTECG_string        object
# EXANG_string          object
# FBS_string            object
# THAL_string           object
# TARGET_string         object
# Race_String           object
# incident             float64
# ExterQual_numeric      int64
# risk                   int64
# dtype: object
# New Column names:
#  age                    int64
# ca                     int64
# trestbps               int64
# chol                   int64
# thalach                int64
# oldpeak              float64
# SEX_string            object
# CP_string             object
# RESTECG_string        object
# EXANG_string          object
# FBS_string            object
# THAL_string           object
# TARGET_string         object
# Race_String           object
# incident             float64
# ExterQual_numeric      int64
# risk                   int64
# dtype: object

# %% [markdown]
# **Important NOTE:** The names of the variable names are changed from this point on.

# %%
# A pandas query is writen as a long string.
"""
It is important that double quotes are used to define the querry and
single quotes used to identify categories (e.g., 'male' below)
"""
df.query("age > 65 and 	SEX_string == 'male'", inplace=False)
# Out:
#      age  ca  trestbps  chol  thalach  oldpeak SEX_string  \
# 51    66   0       120   302      151      0.4       male
# 86    68   1       118   277      151      1.0       male
# 106   69   1       160   234      131      0.1       male
# 145   70   0       156   245      143      0.0       male
# 150   66   0       160   228      138      2.3       male
# 165   67   3       160   286      108      1.5       male
# 166   67   2       120   229      129      2.6       male
# 197   67   2       125   254      163      0.2       male
# 203   68   0       180   274      150      1.6       male
# 225   70   0       145   174      125      2.6       male
# 234   70   3       130   322      109      2.4       male
# 238   77   3       125   304      162      0.0       male
# 240   70   1       160   269      112      2.9       male
# 247   66   3       160   246      120      0.0       male
# 249   69   3       140   254      146      2.0       male
# 253   67   2       100   299      125      0.9       male
# 265   66   1       112   212      132      0.1       male
# 272   67   0       120   237       71      1.0       male
# 293   67   0       152   212      150      0.8       male
# 300   68   2       144   193      141      3.4       male
#
#                CP_string         RESTECG_string EXANG_string FBS_string  \
# 51        typical angina                 normal           no        low
# 86            non-angina  ST-T wave abnormality           no        low
# 106  asymptomatic angina                 normal           no       HIGH
# 145      atypical angina                 normal           no        low
# 150       typical angina                 normal           no        low
# 165       typical angina                 normal          yes        low
# 166       typical angina                 normal          yes        low
# 197       typical angina  ST-T wave abnormality           no       HIGH
# 203           non-angina                 normal          yes       HIGH
# 225       typical angina  ST-T wave abnormality          yes        low
# 234       typical angina                 normal           no        low
# 238       typical angina                 normal          yes        low
# 240           non-angina  ST-T wave abnormality          yes        low
# 247      atypical angina  ST-T wave abnormality          yes        low
# 249           non-angina                 normal           no        low
# 253       typical angina                 normal          yes        low
# 265       typical angina                 normal          yes        low
# 272       typical angina  ST-T wave abnormality           no        low
# 293           non-angina                 normal           no        low
# 300       typical angina  ST-T wave abnormality           no       HIGH
#
#            THAL_string  TARGET_string Race_String  incident  \
# 51        fixed defect   asymptomatic       black     2.172
# 86   reversable defect   asymptomatic       asian     2.442
# 106       fixed defect   asymptomatic       black     0.556
# 145       fixed defect   asymptomatic       white     1.013
# 150             normal   asymptomatic       white     7.853
# 165       fixed defect  heart disease       white     1.202
# 166  reversable defect  heart disease       white    25.727
# 197  reversable defect  heart disease       white     8.853
# 203  reversable defect  heart disease       white     1.837
# 225  reversable defect  heart disease       white     1.101
# 234       fixed defect  heart disease       white     1.305
# 238       fixed defect  heart disease       white     3.127
# 240  reversable defect  heart disease       white     0.360
# 247             normal  heart disease       white     3.095
# 249  reversable defect  heart disease       white    80.756
# 253       fixed defect  heart disease       white     3.324
# 265       fixed defect  heart disease       white     1.562
# 272       fixed defect  heart disease       white     2.983
# 293  reversable defect  heart disease       white     0.627
# 300  reversable defect  heart disease       white    36.971
#
#      ExterQual_numeric  risk
# 51                   0   453
# 86                  -1   428
# 106                  0   365
# 145                 -1   388
# 150                 -1   366
# 165                  0   394
# 166                  0   358
# 197                  0   417
# 203                  0   424
# 225                  1   299
# 234                  0   431
# 238                 -1   466
# 240                  0   381
# 247                  0   366
# 249                  0   400
# 253                  0   424
# 265                 -1   344
# 272                  0   308
# 293                  0   362
# 300                  0   334

# %%
#column names can not have spaces for Pandas Query
#dfTrain.columns=[x.replace(" ", "_") for x in dfTrain.columns]
# using the and to make a multiple criteria
#if pointing to categorical data, the criteria should be in single quotes

df.query("age > 45 and ca>0 and RESTECG_string=='normal'", inplace=False)
# The results should be only the portion of the data that meets the criteria in the query.
# Out:
#      age  ca  trestbps  chol  thalach  oldpeak SEX_string  \
# 28    65   1       140   417      157      0.8     female
# 33    54   1       125   273      152      0.5       male
# 34    51   1       125   213      125      1.4       male
# 40    51   1       140   308      142      1.5     female
# 59    57   1       128   303      159      0.0     female
# 60    71   1       110   265      130      0.0     female
# 93    54   1       132   288      159      0.0     female
# 99    53   3       130   246      173      0.0       male
# 106   69   1       160   234      131      0.1       male
# 129   74   1       120   269      121      0.2     female
# 153   66   1       146   278      152      0.0     female
# 165   67   3       160   286      108      1.5       male
# 166   67   2       120   229      129      2.6       male
# 167   62   2       140   268      160      3.6     female
# 168   63   1       130   254      147      1.4       male
# 170   56   1       130   256      142      0.6       male
# 173   58   2       132   224      173      3.2       male
# 174   60   2       130   206      132      2.4       male
# 179   57   1       150   276      112      0.6       male
# 181   65   3       150   225      114      1.0     female
# 183   58   1       112   230      165      2.5       male
# 187   54   1       124   266      109      2.2       male
# 191   58   3       128   216      131      2.2       male
# 193   60   2       145   282      142      2.8       male
# 199   65   2       110   248      158      0.6       male
# 201   60   1       125   258      141      2.8       male
# 204   62   3       160   164      145      6.2     female
# 206   59   1       110   239      142      1.2       male
# 207   60   2       150   258      157      2.6     female
# 210   57   1       128   229      150      0.4       male
# 214   56   1       125   249      144      1.2       male
# 217   63   3       130   330      132      1.8       male
# 218   65   1       135   254      127      2.8       male
# 219   48   2       130   256      150      0.0       male
# 220   63   3       150   407      154      4.0     female
# 222   65   1       138   282      174      1.4       male
# 223   56   2       200   288      133      4.0     female
# 226   62   1       120   281      103      1.4       male
# 231   57   3       165   289      124      1.0       male
# 232   55   1       160   289      145      0.8       male
# 233   64   1       120   246       96      2.2       male
# 234   70   3       130   322      109      2.4       male
# 236   58   2       125   300      171      0.0       male
# 237   60   2       140   293      170      1.2       male
# 238   77   3       125   304      162      0.0       male
# 242   64   2       145   212      132      2.0       male
# 244   56   1       132   184      105      2.1       male
# 246   56   2       134   409      150      1.9     female
# 248   54   1       192   283      195      0.0       male
# 249   69   3       140   254      146      2.0       male
# 253   67   2       100   299      125      0.9       male
# 256   58   2       128   259      130      3.0       male
# 264   54   1       110   206      108      0.0       male
# 265   66   1       112   212      132      0.1       male
# 267   49   3       118   149      126      0.8       male
# 268   54   2       122   286      116      3.2       male
# 274   47   1       110   275      118      1.0       male
# 278   58   2       136   319      152      0.0     female
# 279   61   1       138   166      125      3.6       male
# 284   61   1       140   207      138      1.9       male
# 287   57   1       154   232      164      0.0       male
# 292   58   2       170   225      146      2.8     female
# 295   63   2       140   187      144      4.0       male
# 297   59   2       164   176       90      1.0       male
# 302   57   1       130   236      174      0.0     female
#
#                CP_string RESTECG_string EXANG_string FBS_string  \
# 28            non-angina         normal           no       HIGH
# 33            non-angina         normal           no        low
# 34   asymptomatic angina         normal          yes        low
# 40            non-angina         normal           no        low
# 59        typical angina         normal           no        low
# 60            non-angina         normal           no       HIGH
# 93       atypical angina         normal          yes       HIGH
# 99            non-angina         normal           no       HIGH
# 106  asymptomatic angina         normal           no       HIGH
# 129      atypical angina         normal          yes        low
# 153           non-angina         normal           no        low
# 165       typical angina         normal          yes        low
# 166       typical angina         normal          yes        low
# 167       typical angina         normal           no        low
# 168       typical angina         normal           no        low
# 170           non-angina         normal          yes       HIGH
# 173           non-angina         normal           no        low
# 174       typical angina         normal          yes        low
# 179       typical angina         normal          yes        low
# 181       typical angina         normal           no        low
# 183           non-angina         normal           no        low
# 187       typical angina         normal          yes        low
# 191       typical angina         normal          yes        low
# 193       typical angina         normal          yes        low
# 199       typical angina         normal           no        low
# 201       typical angina         normal          yes        low
# 204       typical angina         normal           no        low
# 206       typical angina         normal          yes        low
# 207       typical angina         normal           no        low
# 210           non-angina         normal           no        low
# 214       typical angina         normal          yes       HIGH
# 217       typical angina         normal          yes       HIGH
# 218       typical angina         normal           no        low
# 219       typical angina         normal          yes       HIGH
# 220       typical angina         normal           no        low
# 222  asymptomatic angina         normal           no       HIGH
# 223       typical angina         normal          yes       HIGH
# 226      atypical angina         normal           no        low
# 231       typical angina         normal           no       HIGH
# 232       typical angina         normal          yes        low
# 233       typical angina         normal          yes        low
# 234       typical angina         normal           no        low
# 236       typical angina         normal           no        low
# 237       typical angina         normal           no        low
# 238       typical angina         normal          yes        low
# 242       typical angina         normal           no        low
# 244       typical angina         normal          yes        low
# 246       typical angina         normal          yes        low
# 248      atypical angina         normal           no        low
# 249           non-angina         normal           no        low
# 253       typical angina         normal          yes        low
# 256       typical angina         normal          yes        low
# 264       typical angina         normal          yes        low
# 265       typical angina         normal          yes        low
# 267           non-angina         normal           no        low
# 268       typical angina         normal          yes        low
# 274       typical angina         normal          yes        low
# 278      atypical angina         normal           no       HIGH
# 279       typical angina         normal          yes        low
# 284       typical angina         normal          yes        low
# 287      atypical angina         normal           no        low
# 292       typical angina         normal          yes       HIGH
# 295       typical angina         normal          yes        low
# 297       typical angina         normal           no       HIGH
# 302      atypical angina         normal           no        low
#
#            THAL_string  TARGET_string Race_String  incident  \
# 28        fixed defect   asymptomatic       black     1.712
# 33        fixed defect   asymptomatic       black     0.368
# 34        fixed defect   asymptomatic       black     1.143
# 40        fixed defect   asymptomatic       black     3.035
# 59        fixed defect   asymptomatic       black     2.610
# 60        fixed defect   asymptomatic       white     1.839
# 93        fixed defect   asymptomatic       black    19.755
# 99        fixed defect   asymptomatic       black     1.415
# 106       fixed defect   asymptomatic       black     0.556
# 129       fixed defect   asymptomatic       asian     1.050
# 153       fixed defect   asymptomatic       black     1.075
# 165       fixed defect  heart disease       white     1.202
# 166  reversable defect  heart disease       white    25.727
# 167       fixed defect  heart disease       white     3.427
# 168  reversable defect  heart disease       white     1.898
# 170             normal  heart disease       white     2.003
# 173  reversable defect  heart disease       white     2.774
# 174  reversable defect  heart disease       white     2.565
# 179             normal  heart disease       white     2.967
# 181  reversable defect  heart disease       white     1.145
# 183  reversable defect  heart disease       white    17.053
# 187  reversable defect  heart disease       white     1.771
# 191  reversable defect  heart disease       white     1.585
# 193  reversable defect  heart disease       white     2.341
# 199             normal  heart disease       white     4.341
# 201  reversable defect  heart disease       white     1.590
# 204  reversable defect  heart disease       white     2.178
# 206  reversable defect  heart disease       white     0.523
# 207  reversable defect  heart disease       white     1.550
# 210  reversable defect  heart disease       white     4.480
# 214       fixed defect  heart disease       white     3.870
# 217  reversable defect  heart disease       white     4.022
# 218  reversable defect  heart disease       white     3.512
# 219  reversable defect  heart disease       white    15.851
# 220  reversable defect  heart disease       white     4.315
# 222       fixed defect  heart disease       white     0.408
# 223  reversable defect  heart disease       white     0.310
# 226  reversable defect  heart disease       white     0.747
# 231  reversable defect  heart disease       white    85.169
# 232  reversable defect  heart disease       white     9.225
# 233       fixed defect  heart disease       white     1.739
# 234       fixed defect  heart disease       white     1.305
# 236  reversable defect  heart disease       white     1.721
# 237  reversable defect  heart disease       white     2.195
# 238       fixed defect  heart disease       white     3.127
# 242             normal  heart disease       white     1.275
# 244             normal  heart disease       white     0.994
# 246  reversable defect  heart disease       white    36.806
# 248  reversable defect  heart disease       white    20.187
# 249  reversable defect  heart disease       white    80.756
# 253       fixed defect  heart disease       white     3.324
# 256  reversable defect  heart disease       white    13.821
# 264       fixed defect  heart disease       white     2.495
# 265       fixed defect  heart disease       white     1.562
# 267       fixed defect  heart disease       white     2.183
# 268       fixed defect  heart disease       white     1.808
# 274       fixed defect  heart disease       white     0.792
# 278       fixed defect  heart disease       white     7.476
# 279       fixed defect  heart disease       white     1.080
# 284  reversable defect  heart disease       white     2.461
# 287       fixed defect  heart disease       white     0.986
# 292             normal  heart disease       white     1.966
# 295  reversable defect  heart disease       white     2.144
# 297             normal  heart disease       white     4.409
# 302       fixed defect  heart disease       white     5.109
#
#      ExterQual_numeric  risk
# 28                  -1   574
# 33                   1   425
# 34                  -1   338
# 40                  -1   450
# 59                  -1   462
# 60                  -1   395
# 93                  -1   447
# 99                  -1   419
# 106                  0   365
# 129                 -1   390
# 153                  0   430
# 165                  0   394
# 166                  0   358
# 167                  1   428
# 168                  0   401
# 170                  0   398
# 173                 -1   397
# 174                  0   338
# 179                  0   388
# 181                  0   339
# 183                  0   395
# 187                  0   375
# 191                  0   347
# 193                  0   424
# 199                 -1   406
# 201                  0   399
# 204                  1   309
# 206                  0   381
# 207                  0   415
# 210                  0   379
# 214                  0   393
# 217                 -1   462
# 218                  0   381
# 219                 -1   406
# 220                  0   561
# 222                  0   456
# 223                  1   421
# 226                  0   384
# 231                  0   413
# 232                  0   434
# 233                  1   342
# 234                  0   431
# 236                 -1   471
# 237                  0   463
# 238                 -1   466
# 242                  0   344
# 244                  0   289
# 246                  0   559
# 248                 -1   478
# 249                  0   400
# 253                  0   424
# 256                  0   389
# 264                  0   314
# 265                 -1   344
# 267                 -1   275
# 268                  0   402
# 274                  0   393
# 278                 -1   471
# 279                  0   291
# 284                 -1   345
# 287                 -1   396
# 292                  0   371
# 295                 -1   331
# 297                  0   266
# 302                  0   410

# %%
# same query as above but with "or" satement with bar |
#same query but with or statements
df.query("age > 45 | 	ca>0 |RESTECG_string=='normal'",inplace=False)
# Out:
#      age  ca  trestbps  chol  thalach  oldpeak SEX_string  \
# 0     63   0       145   233      150      2.3       male
# 2     41   0       130   204      172      1.4     female
# 3     56   0       120   236      178      0.8       male
# 4     57   0       120   354      163      0.6     female
# 5     57   0       140   192      148      0.4       male
# 6     56   0       140   294      153      1.3     female
# 8     52   0       172   199      162      0.5       male
# 9     57   0       150   168      174      1.6       male
# 10    54   0       140   239      160      1.2       male
# 11    48   0       130   275      139      0.2     female
# 12    49   0       130   266      171      0.6       male
# 13    64   0       110   211      144      1.8       male
# 14    58   0       150   283      162      1.0     female
# 15    50   0       120   219      158      1.6     female
# 16    58   0       120   340      172      0.0     female
# 17    66   0       150   226      114      2.6     female
# 19    69   2       140   239      151      1.8     female
# 20    59   0       135   234      161      0.5       male
# 23    61   0       150   243      137      1.0       male
# 25    71   2       160   302      162      0.4     female
# 26    59   0       150   212      157      1.6       male
# 27    51   0       110   175      123      0.6       male
# 28    65   1       140   417      157      0.8     female
# 29    53   0       130   197      152      1.2       male
# 30    41   1       105   198      168      0.0     female
# 31    65   0       120   177      140      0.4       male
# 32    44   0       130   219      188      0.0       male
# 33    54   1       125   273      152      0.5       male
# 34    51   1       125   213      125      1.4       male
# 35    46   0       142   177      160      1.4     female
# 36    54   0       135   304      170      0.0     female
# 37    54   0       150   232      165      1.6       male
# 38    65   0       155   269      148      0.8     female
# 39    65   0       160   360      151      0.8     female
# 40    51   1       140   308      142      1.5     female
# 41    48   0       130   245      180      0.2       male
# 42    45   0       104   208      148      3.0       male
# 43    53   0       130   264      143      0.4     female
# 44    39   0       140   321      182      0.0       male
# 45    52   0       120   325      172      0.2       male
# 46    44   0       140   235      180      0.0       male
# 47    47   0       138   257      156      0.0       male
# 48    53   0       128   216      115      0.0     female
# 49    53   0       138   234      160      0.0     female
# 50    51   0       130   256      149      0.5     female
# 51    66   0       120   302      151      0.4       male
# 52    62   3       130   231      146      1.8       male
# 54    63   0       135   252      172      0.0     female
# 55    52   1       134   201      158      0.8       male
# 56    48   0       122   222      186      0.0       male
# 57    45   0       115   260      185      0.0       male
# 58    34   0       118   182      174      0.0       male
# 59    57   1       128   303      159      0.0     female
# 60    71   1       110   265      130      0.0     female
# 61    54   0       108   309      156      0.0       male
# 62    52   0       118   186      190      0.0       male
# 64    58   0       140   211      165      0.0       male
# 66    51   0       100   222      143      1.2       male
# 67    45   0       130   234      175      0.6     female
# 69    62   0       124   209      163      0.0     female
# 70    54   0       120   258      147      0.4       male
# 71    51   1        94   227      154      0.0       male
# 72    29   0       130   204      202      0.0       male
# 73    51   0       140   261      186      0.0       male
# 75    55   0       135   250      161      1.4     female
# 76    51   0       125   245      166      2.4       male
# 77    59   0       140   221      164      0.0       male
# 78    52   0       128   205      184      0.0       male
# 79    58   0       105   240      154      0.6       male
# 81    45   0       128   308      170      0.0       male
# 82    60   1       102   318      160      0.0     female
# 83    52   0       152   298      178      1.2       male
# 84    42   0       102   265      122      0.6     female
# 85    67   0       115   564      160      1.6     female
# 86    68   1       118   277      151      1.0       male
# 87    46   0       101   197      156      0.0       male
# 88    54   0       110   214      158      1.6     female
# 89    58   0       100   248      122      1.0     female
# 90    48   2       124   255      175      0.0       male
# 91    57   0       132   207      168      0.0       male
# 92    52   0       138   223      169      0.0       male
# 93    54   1       132   288      159      0.0     female
# 95    53   0       142   226      111      0.0       male
# 96    62   0       140   394      157      1.2     female
# 97    52   3       108   233      147      0.1       male
# 98    43   1       130   315      162      1.9       male
# 99    53   3       130   246      173      0.0       male
# 100   42   2       148   244      178      0.8       male
# 101   59   0       178   270      145      4.2       male
# 102   63   2       140   195      179      0.0     female
# 104   50   0       129   196      163      0.0       male
# 105   68   0       120   211      115      1.5     female
# 106   69   1       160   234      131      0.1       male
# 107   45   0       138   236      152      0.2     female
# 108   50   0       120   244      162      1.1     female
# 109   50   0       110   254      159      0.0     female
# 110   64   0       180   325      154      0.0     female
# 111   57   1       150   126      173      0.2       male
# 112   64   0       140   313      133      0.2     female
# 114   55   0       130   262      155      0.0       male
# 116   41   0       130   214      168      2.0       male
# 117   56   0       120   193      162      1.9       male
# 118   46   0       105   204      172      0.0     female
# 119   46   0       138   243      152      0.0     female
# 120   64   2       130   303      122      2.0     female
# 121   59   0       138   271      182      0.0       male
# 122   41   0       112   268      172      0.0     female
# 123   54   0       108   267      167      0.0     female
# 126   47   0       112   204      143      0.1       male
# 127   67   1       152   277      172      0.0     female
# 128   52   0       136   196      169      0.1     female
# 129   74   1       120   269      121      0.2     female
# 130   54   1       160   201      163      0.0     female
# 131   49   0       134   271      162      0.0     female
# 135   49   0       130   269      163      0.0     female
# 136   60   0       120   178       96      0.0     female
# 137   62   0       128   208      140      0.0       male
# 138   57   0       110   201      126      1.5       male
# 139   64   1       128   263      105      0.2       male
# 140   51   0       120   295      157      0.6     female
# 143   67   2       106   223      142      0.3     female
# 144   76   0       140   197      116      1.1     female
# 145   70   0       156   245      143      0.0       male
# 146   44   1       118   242      149      0.3     female
# 147   60   0       150   240      171      0.9     female
# 150   66   0       160   228      138      2.3       male
# 151   71   0       112   149      125      1.6     female
# 152   64   0       170   227      155      0.6       male
# 153   66   1       146   278      152      0.0     female
# 155   58   0       130   197      131      0.6     female
# 156   47   0       130   253      179      0.0       male
# 158   58   0       125   220      144      0.4       male
# 159   56   0       130   221      163      0.0       male
# 160   56   0       120   240      169      0.0       male
# 161   55   0       132   342      166      1.2     female
# 165   67   3       160   286      108      1.5       male
# 166   67   2       120   229      129      2.6       male
# 167   62   2       140   268      160      3.6     female
# 168   63   1       130   254      147      1.4       male
# 169   53   0       140   203      155      3.1       male
# 170   56   1       130   256      142      0.6       male
# 171   48   0       110   229      168      1.0       male
# 172   58   0       120   284      160      1.8       male
# 173   58   2       132   224      173      3.2       male
# 174   60   2       130   206      132      2.4       male
# 175   40   0       110   167      114      2.0       male
# 176   60   2       117   230      160      1.4       male
# 177   64   0       140   335      158      0.0       male
# 178   43   0       120   177      120      2.5       male
# 179   57   1       150   276      112      0.6       male
# 180   55   1       132   353      132      1.2       male
# 181   65   3       150   225      114      1.0     female
# 182   61   0       130   330      169      0.0     female
# 183   58   1       112   230      165      2.5       male
# 184   50   0       150   243      128      2.6       male
# 185   44   1       112   290      153      0.0       male
# 186   60   1       130   253      144      1.4       male
# 187   54   1       124   266      109      2.2       male
# 188   50   1       140   233      163      0.6       male
# 189   41   0       110   172      158      0.0       male
# 190   51   0       130   305      142      1.2     female
# 191   58   3       128   216      131      2.2       male
# 192   54   1       120   188      113      1.4       male
# 193   60   2       145   282      142      2.8       male
# 194   60   0       140   185      155      3.0       male
# 195   59   0       170   326      140      3.4       male
# 196   46   0       150   231      147      3.6       male
# 197   67   2       125   254      163      0.2       male
# 198   62   2       120   267       99      1.8       male
# 199   65   2       110   248      158      0.6       male
# 200   44   1       110   197      177      0.0       male
# 201   60   1       125   258      141      2.8       male
# 202   58   0       150   270      111      0.8       male
# 203   68   0       180   274      150      1.6       male
# 204   62   3       160   164      145      6.2     female
# 205   52   1       128   255      161      0.0       male
# 206   59   1       110   239      142      1.2       male
# 207   60   2       150   258      157      2.6     female
# 208   49   3       120   188      139      2.0       male
# 209   59   1       140   177      162      0.0       male
# 210   57   1       128   229      150      0.4       male
# 211   61   1       120   260      140      3.6       male
# 213   61   0       145   307      146      1.0     female
# 214   56   1       125   249      144      1.2       male
# 215   43   0       132   341      136      3.0     female
# 216   62   1       130   263       97      1.2     female
# 217   63   3       130   330      132      1.8       male
# 218   65   1       135   254      127      2.8       male
# 219   48   2       130   256      150      0.0       male
# 220   63   3       150   407      154      4.0     female
# 221   55   0       140   217      111      5.6       male
# 222   65   1       138   282      174      1.4       male
# 223   56   2       200   288      133      4.0     female
# 224   54   1       110   239      126      2.8       male
# 225   70   0       145   174      125      2.6       male
# 226   62   1       120   281      103      1.4       male
# 228   59   0       170   288      159      0.2       male
# 229   64   0       125   309      131      1.8       male
# 230   47   0       108   243      152      0.0       male
# 231   57   3       165   289      124      1.0       male
# 232   55   1       160   289      145      0.8       male
# 233   64   1       120   246       96      2.2       male
# 234   70   3       130   322      109      2.4       male
# 235   51   0       140   299      173      1.6       male
# 236   58   2       125   300      171      0.0       male
# 237   60   2       140   293      170      1.2       male
# 238   77   3       125   304      162      0.0       male
# 239   35   0       126   282      156      0.0       male
# 240   70   1       160   269      112      2.9       male
# 241   59   0       174   249      143      0.0     female
# 242   64   2       145   212      132      2.0       male
# 243   57   1       152   274       88      1.2       male
# 244   56   1       132   184      105      2.1       male
# 245   48   0       124   274      166      0.5       male
# 246   56   2       134   409      150      1.9     female
# 247   66   3       160   246      120      0.0       male
# 248   54   1       192   283      195      0.0       male
# 249   69   3       140   254      146      2.0       male
# 250   51   3       140   298      122      4.2       male
# 251   43   0       132   247      143      0.1       male
# 252   62   3       138   294      106      1.9     female
# 253   67   2       100   299      125      0.9       male
# 254   59   0       160   273      125      0.0       male
# 255   45   3       142   309      147      0.0       male
# 256   58   2       128   259      130      3.0       male
# 257   50   0       144   200      126      0.9       male
# 258   62   0       150   244      154      1.4     female
# 260   66   2       178   228      165      1.0     female
# 261   52   1       112   230      160      0.0       male
# 262   53   2       123   282       95      2.0       male
# 263   63   2       108   269      169      1.8     female
# 264   54   1       110   206      108      0.0       male
# 265   66   1       112   212      132      0.1       male
# 266   55   0       180   327      117      3.4     female
# 267   49   3       118   149      126      0.8       male
# 268   54   2       122   286      116      3.2       male
# 269   56   0       130   283      103      1.6       male
# 270   46   0       120   249      144      0.8       male
# 271   61   2       134   234      145      2.6       male
# 272   67   0       120   237       71      1.0       male
# 273   58   1       100   234      156      0.1       male
# 274   47   1       110   275      118      1.0       male
# 275   52   2       125   212      168      1.0       male
# 276   58   1       146   218      105      2.0       male
# 277   57   0       124   261      141      0.3       male
# 278   58   2       136   319      152      0.0     female
# 279   61   1       138   166      125      3.6       male
# 281   52   0       128   204      156      1.0       male
# 282   59   1       126   218      134      2.2       male
# 284   61   1       140   207      138      1.9       male
# 285   46   2       140   311      120      1.8       male
# 286   59   2       134   204      162      0.8       male
# 287   57   1       154   232      164      0.0       male
# 288   57   1       110   335      143      3.0       male
# 289   55   1       128   205      130      2.0     female
# 290   61   1       148   203      161      0.0       male
# 291   58   3       114   318      140      4.4       male
# 292   58   2       170   225      146      2.8     female
# 293   67   0       152   212      150      0.8       male
# 295   63   2       140   187      144      4.0       male
# 296   63   0       124   197      136      0.0     female
# 297   59   2       164   176       90      1.0       male
# 298   57   0       140   241      123      0.2     female
# 300   68   2       144   193      141      3.4       male
# 301   57   1       130   131      115      1.2       male
# 302   57   1       130   236      174      0.0     female
#
#                CP_string                RESTECG_string EXANG_string  \
# 0    asymptomatic angina                        normal           no
# 2        atypical angina                        normal           no
# 3        atypical angina         ST-T wave abnormality           no
# 4         typical angina         ST-T wave abnormality          yes
# 5         typical angina         ST-T wave abnormality           no
# 6        atypical angina                        normal           no
# 8             non-angina         ST-T wave abnormality           no
# 9             non-angina         ST-T wave abnormality           no
# 10        typical angina         ST-T wave abnormality           no
# 11            non-angina         ST-T wave abnormality           no
# 12       atypical angina         ST-T wave abnormality           no
# 13   asymptomatic angina                        normal          yes
# 14   asymptomatic angina                        normal           no
# 15            non-angina         ST-T wave abnormality           no
# 16            non-angina         ST-T wave abnormality           no
# 17   asymptomatic angina         ST-T wave abnormality           no
# 19   asymptomatic angina         ST-T wave abnormality           no
# 20        typical angina         ST-T wave abnormality           no
# 23            non-angina         ST-T wave abnormality          yes
# 25       atypical angina         ST-T wave abnormality           no
# 26            non-angina         ST-T wave abnormality           no
# 27            non-angina         ST-T wave abnormality           no
# 28            non-angina                        normal           no
# 29            non-angina                        normal           no
# 30       atypical angina         ST-T wave abnormality           no
# 31        typical angina         ST-T wave abnormality           no
# 32       atypical angina                        normal           no
# 33            non-angina                        normal           no
# 34   asymptomatic angina                        normal          yes
# 35            non-angina                        normal          yes
# 36            non-angina         ST-T wave abnormality           no
# 37            non-angina                        normal           no
# 38            non-angina         ST-T wave abnormality           no
# 39            non-angina                        normal           no
# 40            non-angina                        normal           no
# 41       atypical angina                        normal           no
# 42        typical angina                        normal          yes
# 43        typical angina                        normal           no
# 44            non-angina                        normal           no
# 45       atypical angina         ST-T wave abnormality           no
# 46            non-angina                        normal           no
# 47            non-angina                        normal           no
# 48            non-angina                        normal           no
# 49        typical angina                        normal           no
# 50            non-angina                        normal           no
# 51        typical angina                        normal           no
# 52            non-angina         ST-T wave abnormality           no
# 54            non-angina                        normal           no
# 55       atypical angina         ST-T wave abnormality           no
# 56        typical angina                        normal           no
# 57        typical angina                        normal           no
# 58   asymptomatic angina                        normal           no
# 59        typical angina                        normal           no
# 60            non-angina                        normal           no
# 61       atypical angina         ST-T wave abnormality           no
# 62   asymptomatic angina                        normal           no
# 64            non-angina                        normal           no
# 66            non-angina         ST-T wave abnormality          yes
# 67       atypical angina                        normal           no
# 69        typical angina         ST-T wave abnormality           no
# 70            non-angina                        normal           no
# 71            non-angina         ST-T wave abnormality          yes
# 72       atypical angina                        normal           no
# 73        typical angina                        normal          yes
# 75       atypical angina                        normal           no
# 76            non-angina                        normal           no
# 77       atypical angina         ST-T wave abnormality          yes
# 78       atypical angina         ST-T wave abnormality           no
# 79            non-angina                        normal          yes
# 81       atypical angina                        normal           no
# 82            non-angina         ST-T wave abnormality           no
# 83   asymptomatic angina         ST-T wave abnormality           no
# 84        typical angina                        normal           no
# 85            non-angina                        normal           no
# 86            non-angina         ST-T wave abnormality           no
# 87       atypical angina         ST-T wave abnormality           no
# 88            non-angina         ST-T wave abnormality           no
# 89        typical angina                        normal           no
# 90            non-angina         ST-T wave abnormality           no
# 91        typical angina         ST-T wave abnormality          yes
# 92            non-angina         ST-T wave abnormality           no
# 93       atypical angina                        normal          yes
# 95        typical angina                        normal          yes
# 96        typical angina                        normal           no
# 97        typical angina         ST-T wave abnormality           no
# 98            non-angina         ST-T wave abnormality           no
# 99            non-angina                        normal           no
# 100  asymptomatic angina                        normal           no
# 101  asymptomatic angina                        normal           no
# 102      atypical angina         ST-T wave abnormality           no
# 104           non-angina         ST-T wave abnormality           no
# 105           non-angina                        normal           no
# 106  asymptomatic angina                        normal           no
# 107       typical angina                        normal          yes
# 108      atypical angina         ST-T wave abnormality           no
# 109       typical angina                        normal           no
# 110       typical angina         ST-T wave abnormality          yes
# 111           non-angina         ST-T wave abnormality           no
# 112           non-angina         ST-T wave abnormality           no
# 114      atypical angina         ST-T wave abnormality           no
# 116           non-angina                        normal           no
# 117  asymptomatic angina                        normal           no
# 118      atypical angina         ST-T wave abnormality           no
# 119       typical angina                        normal          yes
# 120       typical angina         ST-T wave abnormality           no
# 121       typical angina                        normal           no
# 122           non-angina                        normal          yes
# 123           non-angina                        normal           no
# 126       typical angina         ST-T wave abnormality           no
# 127           non-angina         ST-T wave abnormality           no
# 128           non-angina                        normal           no
# 129      atypical angina                        normal          yes
# 130           non-angina         ST-T wave abnormality           no
# 131      atypical angina         ST-T wave abnormality           no
# 135       typical angina         ST-T wave abnormality           no
# 136           non-angina         ST-T wave abnormality           no
# 137      atypical angina                        normal           no
# 138       typical angina         ST-T wave abnormality          yes
# 139       typical angina         ST-T wave abnormality          yes
# 140           non-angina                        normal           no
# 143       typical angina         ST-T wave abnormality           no
# 144           non-angina  left ventricular hypertrophy           no
# 145      atypical angina                        normal           no
# 146           non-angina         ST-T wave abnormality           no
# 147  asymptomatic angina         ST-T wave abnormality           no
# 150       typical angina                        normal           no
# 151       typical angina         ST-T wave abnormality           no
# 152  asymptomatic angina                        normal           no
# 153           non-angina                        normal           no
# 155       typical angina         ST-T wave abnormality           no
# 156           non-angina         ST-T wave abnormality           no
# 158      atypical angina         ST-T wave abnormality           no
# 159      atypical angina                        normal           no
# 160      atypical angina         ST-T wave abnormality           no
# 161      atypical angina         ST-T wave abnormality           no
# 165       typical angina                        normal          yes
# 166       typical angina                        normal          yes
# 167       typical angina                        normal           no
# 168       typical angina                        normal           no
# 169       typical angina                        normal          yes
# 170           non-angina                        normal          yes
# 171      atypical angina         ST-T wave abnormality           no
# 172      atypical angina                        normal           no
# 173           non-angina                        normal           no
# 174       typical angina                        normal          yes
# 175       typical angina                        normal          yes
# 176       typical angina         ST-T wave abnormality          yes
# 177           non-angina         ST-T wave abnormality           no
# 178       typical angina                        normal          yes
# 179       typical angina                        normal          yes
# 180       typical angina         ST-T wave abnormality          yes
# 181       typical angina                        normal           no
# 182       typical angina                        normal           no
# 183           non-angina                        normal           no
# 184       typical angina                        normal           no
# 185       typical angina                        normal           no
# 186       typical angina         ST-T wave abnormality          yes
# 187       typical angina                        normal          yes
# 188           non-angina         ST-T wave abnormality           no
# 189       typical angina                        normal           no
# 190       typical angina         ST-T wave abnormality          yes
# 191       typical angina                        normal          yes
# 192       typical angina         ST-T wave abnormality           no
# 193       typical angina                        normal          yes
# 194           non-angina                        normal           no
# 195       typical angina                        normal          yes
# 196           non-angina         ST-T wave abnormality           no
# 197       typical angina         ST-T wave abnormality           no
# 198       typical angina         ST-T wave abnormality          yes
# 199       typical angina                        normal           no
# 200       typical angina                        normal           no
# 201       typical angina                        normal          yes
# 202       typical angina                        normal          yes
# 203           non-angina                        normal          yes
# 204       typical angina                        normal           no
# 205       typical angina         ST-T wave abnormality          yes
# 206       typical angina                        normal          yes
# 207       typical angina                        normal           no
# 208           non-angina         ST-T wave abnormality           no
# 209       typical angina         ST-T wave abnormality          yes
# 210           non-angina                        normal           no
# 211       typical angina         ST-T wave abnormality          yes
# 213       typical angina                        normal          yes
# 214       typical angina                        normal          yes
# 215       typical angina                        normal          yes
# 216           non-angina         ST-T wave abnormality           no
# 217       typical angina                        normal          yes
# 218       typical angina                        normal           no
# 219       typical angina                        normal          yes
# 220       typical angina                        normal           no
# 221       typical angina         ST-T wave abnormality          yes
# 222  asymptomatic angina                        normal           no
# 223       typical angina                        normal          yes
# 224       typical angina         ST-T wave abnormality          yes
# 225       typical angina         ST-T wave abnormality          yes
# 226      atypical angina                        normal           no
# 228  asymptomatic angina                        normal           no
# 229           non-angina         ST-T wave abnormality          yes
# 230           non-angina         ST-T wave abnormality           no
# 231       typical angina                        normal           no
# 232       typical angina                        normal          yes
# 233       typical angina                        normal          yes
# 234       typical angina                        normal           no
# 235       typical angina         ST-T wave abnormality          yes
# 236       typical angina                        normal           no
# 237       typical angina                        normal           no
# 238       typical angina                        normal          yes
# 239       typical angina                        normal          yes
# 240           non-angina         ST-T wave abnormality          yes
# 241       typical angina         ST-T wave abnormality          yes
# 242       typical angina                        normal           no
# 243       typical angina         ST-T wave abnormality          yes
# 244       typical angina                        normal          yes
# 245       typical angina                        normal           no
# 246       typical angina                        normal          yes
# 247      atypical angina         ST-T wave abnormality          yes
# 248      atypical angina                        normal           no
# 249           non-angina                        normal           no
# 250       typical angina         ST-T wave abnormality          yes
# 251       typical angina                        normal          yes
# 252       typical angina         ST-T wave abnormality           no
# 253       typical angina                        normal          yes
# 254  asymptomatic angina                        normal           no
# 255       typical angina                        normal          yes
# 256       typical angina                        normal          yes
# 257       typical angina                        normal          yes
# 258       typical angina         ST-T wave abnormality          yes
# 260       typical angina         ST-T wave abnormality          yes
# 261       typical angina         ST-T wave abnormality           no
# 262       typical angina         ST-T wave abnormality          yes
# 263       typical angina         ST-T wave abnormality          yes
# 264       typical angina                        normal          yes
# 265       typical angina                        normal          yes
# 266       typical angina  left ventricular hypertrophy          yes
# 267           non-angina                        normal           no
# 268       typical angina                        normal          yes
# 269       typical angina                        normal          yes
# 270       typical angina                        normal           no
# 271  asymptomatic angina         ST-T wave abnormality           no
# 272       typical angina         ST-T wave abnormality           no
# 273       typical angina         ST-T wave abnormality           no
# 274       typical angina                        normal          yes
# 275       typical angina         ST-T wave abnormality           no
# 276       typical angina         ST-T wave abnormality           no
# 277      atypical angina         ST-T wave abnormality           no
# 278      atypical angina                        normal           no
# 279       typical angina                        normal          yes
# 281       typical angina         ST-T wave abnormality          yes
# 282           non-angina         ST-T wave abnormality           no
# 284       typical angina                        normal          yes
# 285       typical angina         ST-T wave abnormality          yes
# 286  asymptomatic angina         ST-T wave abnormality           no
# 287      atypical angina                        normal           no
# 288       typical angina         ST-T wave abnormality          yes
# 289       typical angina  left ventricular hypertrophy          yes
# 290       typical angina         ST-T wave abnormality           no
# 291       typical angina  left ventricular hypertrophy           no
# 292       typical angina                        normal          yes
# 293           non-angina                        normal           no
# 295       typical angina                        normal          yes
# 296       typical angina         ST-T wave abnormality          yes
# 297       typical angina                        normal           no
# 298       typical angina         ST-T wave abnormality          yes
# 300       typical angina         ST-T wave abnormality           no
# 301       typical angina         ST-T wave abnormality          yes
# 302      atypical angina                        normal           no
#
#     FBS_string        THAL_string  TARGET_string Race_String  incident  \
# 0         HIGH             normal   asymptomatic       white     3.803
# 2          low       fixed defect   asymptomatic       white     1.854
# 3          low       fixed defect   asymptomatic       black    23.172
# 4          low       fixed defect   asymptomatic       white    13.378
# 5          low             normal   asymptomatic       black     6.235
# 6          low       fixed defect   asymptomatic       white     2.263
# 8         HIGH  reversable defect   asymptomatic       asian     2.312
# 9          low       fixed defect   asymptomatic       asian     3.670
# 10         low       fixed defect   asymptomatic       asian     0.502
# 11         low       fixed defect   asymptomatic       black     5.262
# 12         low       fixed defect   asymptomatic       asian     1.470
# 13         low       fixed defect   asymptomatic       asian    23.084
# 14        HIGH       fixed defect   asymptomatic       black     1.395
# 15         low       fixed defect   asymptomatic       black     1.986
# 16         low       fixed defect   asymptomatic       asian     1.817
# 17         low       fixed defect   asymptomatic       white     7.887
# 19         low       fixed defect   asymptomatic       black     3.403
# 20         low  reversable defect   asymptomatic       black     2.432
# 23        HIGH       fixed defect   asymptomatic       asian     1.149
# 25         low       fixed defect   asymptomatic       asian     0.540
# 26        HIGH       fixed defect   asymptomatic       black     2.934
# 27         low       fixed defect   asymptomatic       black     0.487
# 28        HIGH       fixed defect   asymptomatic       black     1.712
# 29        HIGH       fixed defect   asymptomatic       asian     1.686
# 30         low       fixed defect   asymptomatic       black     6.972
# 31         low  reversable defect   asymptomatic       asian     1.979
# 32         low       fixed defect   asymptomatic       black     1.575
# 33         low       fixed defect   asymptomatic       black     0.368
# 34         low       fixed defect   asymptomatic       black     1.143
# 35         low       fixed defect   asymptomatic       white     1.672
# 36        HIGH       fixed defect   asymptomatic       black    19.394
# 37         low  reversable defect   asymptomatic       black    19.776
# 38         low       fixed defect   asymptomatic       black     3.761
# 39         low       fixed defect   asymptomatic       asian     2.148
# 40         low       fixed defect   asymptomatic       black     3.035
# 41         low       fixed defect   asymptomatic       white     1.726
# 42         low       fixed defect   asymptomatic       asian     3.265
# 43         low       fixed defect   asymptomatic       asian     3.284
# 44         low       fixed defect   asymptomatic       white     2.704
# 45         low       fixed defect   asymptomatic       asian     2.167
# 46         low       fixed defect   asymptomatic       black     0.849
# 47         low       fixed defect   asymptomatic       white     1.346
# 48         low                NaN   asymptomatic       asian     3.265
# 49         low       fixed defect   asymptomatic       asian     3.808
# 50         low       fixed defect   asymptomatic       black     3.360
# 51         low       fixed defect   asymptomatic       black     2.172
# 52         low  reversable defect   asymptomatic       asian     2.075
# 54         low       fixed defect   asymptomatic       black     4.173
# 55         low       fixed defect   asymptomatic       black     1.076
# 56         low       fixed defect   asymptomatic       black     5.528
# 57         low       fixed defect   asymptomatic       white     2.854
# 58         low       fixed defect   asymptomatic       white     0.718
# 59         low       fixed defect   asymptomatic       black     2.610
# 60        HIGH       fixed defect   asymptomatic       white     1.839
# 61         low  reversable defect   asymptomatic       asian    53.684
# 62         low             normal   asymptomatic       black     0.628
# 64        HIGH       fixed defect   asymptomatic       white     2.393
# 66         low       fixed defect   asymptomatic       black     5.427
# 67         low       fixed defect   asymptomatic       black     0.522
# 69         low       fixed defect   asymptomatic       black    35.379
# 70         low  reversable defect   asymptomatic       black     1.988
# 71         low  reversable defect   asymptomatic       black     8.585
# 72         low       fixed defect   asymptomatic       black     1.778
# 73         low       fixed defect   asymptomatic       white     2.113
# 75         low       fixed defect   asymptomatic       asian     3.038
# 76        HIGH       fixed defect   asymptomatic       black     0.480
# 77         low       fixed defect   asymptomatic       asian     1.634
# 78        HIGH       fixed defect   asymptomatic       white     6.190
# 79         low  reversable defect   asymptomatic       black     5.174
# 81         low       fixed defect   asymptomatic       asian    18.936
# 82         low       fixed defect   asymptomatic       asian     3.618
# 83        HIGH  reversable defect   asymptomatic       black     4.987
# 84         low       fixed defect   asymptomatic       asian     4.942
# 85         low  reversable defect   asymptomatic       asian    11.587
# 86         low  reversable defect   asymptomatic       asian     2.442
# 87        HIGH  reversable defect   asymptomatic       asian     2.918
# 88         low       fixed defect   asymptomatic       white     6.805
# 89         low       fixed defect   asymptomatic       white     4.618
# 90        HIGH       fixed defect   asymptomatic       black    13.855
# 91         low  reversable defect   asymptomatic       asian    10.624
# 92         low       fixed defect   asymptomatic       black     0.869
# 93        HIGH       fixed defect   asymptomatic       black    19.755
# 95         low  reversable defect   asymptomatic       white    22.740
# 96         low       fixed defect   asymptomatic       asian     1.047
# 97        HIGH  reversable defect   asymptomatic       asian     0.943
# 98         low       fixed defect   asymptomatic       asian     5.760
# 99        HIGH       fixed defect   asymptomatic       black     1.415
# 100        low       fixed defect   asymptomatic       white     0.754
# 101        low  reversable defect   asymptomatic       black     0.622
# 102        low       fixed defect   asymptomatic       white     2.552
# 104        low       fixed defect   asymptomatic       white    15.947
# 105        low       fixed defect   asymptomatic       black     3.524
# 106       HIGH       fixed defect   asymptomatic       black     0.556
# 107        low       fixed defect   asymptomatic       white     1.690
# 108        low       fixed defect   asymptomatic       white     4.041
# 109        low       fixed defect   asymptomatic       black     6.180
# 110        low       fixed defect   asymptomatic       white     1.593
# 111       HIGH  reversable defect   asymptomatic       black     0.355
# 112        low  reversable defect   asymptomatic       asian     7.607
# 114        low       fixed defect   asymptomatic       black     4.199
# 116        low       fixed defect   asymptomatic       white     0.760
# 117        low  reversable defect   asymptomatic       asian     0.824
# 118        low       fixed defect   asymptomatic       white     7.628
# 119        low       fixed defect   asymptomatic       black     1.395
# 120        low       fixed defect   asymptomatic       asian     1.911
# 121        low       fixed defect   asymptomatic       black     1.502
# 122        low       fixed defect   asymptomatic       white     3.333
# 123        low       fixed defect   asymptomatic       asian    37.262
# 126        low       fixed defect   asymptomatic       black     0.745
# 127        low       fixed defect   asymptomatic       black     4.420
# 128        low       fixed defect   asymptomatic       asian     1.588
# 129        low       fixed defect   asymptomatic       asian     1.050
# 130        low       fixed defect   asymptomatic       black     1.526
# 131        low       fixed defect   asymptomatic       white     7.936
# 135        low       fixed defect   asymptomatic       black     3.197
# 136       HIGH       fixed defect   asymptomatic       black     2.908
# 137       HIGH       fixed defect   asymptomatic       black    12.287
# 138        low             normal   asymptomatic       black     3.557
# 139        low  reversable defect   asymptomatic       black     6.252
# 140        low       fixed defect   asymptomatic       white     1.151
# 143        low       fixed defect   asymptomatic       asian     3.583
# 144        low       fixed defect   asymptomatic       asian     3.376
# 145        low       fixed defect   asymptomatic       white     1.013
# 146        low       fixed defect   asymptomatic       black     2.201
# 147        low       fixed defect   asymptomatic       black     1.487
# 150        low             normal   asymptomatic       white     7.853
# 151        low       fixed defect   asymptomatic       asian     4.981
# 152        low  reversable defect   asymptomatic       asian     1.066
# 153        low       fixed defect   asymptomatic       black     1.075
# 155        low       fixed defect   asymptomatic       white     6.907
# 156        low       fixed defect   asymptomatic       asian     7.336
# 158        low  reversable defect   asymptomatic       black     0.829
# 159        low  reversable defect   asymptomatic       white     2.396
# 160        low       fixed defect   asymptomatic       black     0.038
# 161        low       fixed defect   asymptomatic       black     0.101
# 165        low       fixed defect  heart disease       white     1.202
# 166        low  reversable defect  heart disease       white    25.727
# 167        low       fixed defect  heart disease       white     3.427
# 168        low  reversable defect  heart disease       white     1.898
# 169       HIGH  reversable defect  heart disease       white     1.319
# 170       HIGH             normal  heart disease       white     2.003
# 171        low  reversable defect  heart disease       white     2.450
# 172        low       fixed defect  heart disease       white     7.077
# 173        low  reversable defect  heart disease       white     2.774
# 174        low  reversable defect  heart disease       white     2.565
# 175        low  reversable defect  heart disease       white     1.901
# 176       HIGH  reversable defect  heart disease       white     1.418
# 177        low       fixed defect  heart disease       white     1.008
# 178        low  reversable defect  heart disease       white     5.429
# 179        low             normal  heart disease       white     2.967
# 180        low  reversable defect  heart disease       white     3.450
# 181        low  reversable defect  heart disease       white     1.145
# 182        low       fixed defect  heart disease       white     4.470
# 183        low  reversable defect  heart disease       white    17.053
# 184        low  reversable defect  heart disease       white     4.271
# 185        low       fixed defect  heart disease       white     1.441
# 186        low  reversable defect  heart disease       white     5.546
# 187        low  reversable defect  heart disease       white     1.771
# 188        low  reversable defect  heart disease       white     2.970
# 189        low  reversable defect  heart disease       white     1.667
# 190        low  reversable defect  heart disease       white     9.506
# 191        low  reversable defect  heart disease       white     1.585
# 192        low  reversable defect  heart disease       white     1.074
# 193        low  reversable defect  heart disease       white     2.341
# 194        low       fixed defect  heart disease       white     3.067
# 195        low  reversable defect  heart disease       white     1.986
# 196        low       fixed defect  heart disease       white    10.771
# 197       HIGH  reversable defect  heart disease       white     8.853
# 198        low  reversable defect  heart disease       white     3.392
# 199        low             normal  heart disease       white     4.341
# 200        low       fixed defect  heart disease       white     1.941
# 201        low  reversable defect  heart disease       white     1.590
# 202        low  reversable defect  heart disease       white     1.892
# 203       HIGH  reversable defect  heart disease       white     1.837
# 204        low  reversable defect  heart disease       white     2.178
# 205        low  reversable defect  heart disease       white     1.954
# 206        low  reversable defect  heart disease       white     0.523
# 207        low  reversable defect  heart disease       white     1.550
# 208        low  reversable defect  heart disease       white     2.620
# 209        low  reversable defect  heart disease       white     0.365
# 210        low  reversable defect  heart disease       white     4.480
# 211        low  reversable defect  heart disease       white     1.815
# 213        low  reversable defect  heart disease       white     3.606
# 214       HIGH       fixed defect  heart disease       white     3.870
# 215       HIGH  reversable defect  heart disease       white     2.594
# 216        low  reversable defect  heart disease       white     0.919
# 217       HIGH  reversable defect  heart disease       white     4.022
# 218        low  reversable defect  heart disease       white     3.512
# 219       HIGH  reversable defect  heart disease       white    15.851
# 220        low  reversable defect  heart disease       white     4.315
# 221        low  reversable defect  heart disease       white    72.143
# 222       HIGH       fixed defect  heart disease       white     0.408
# 223       HIGH  reversable defect  heart disease       white     0.310
# 224        low  reversable defect  heart disease       white     0.887
# 225        low  reversable defect  heart disease       white     1.101
# 226        low  reversable defect  heart disease       white     0.747
# 228        low  reversable defect  heart disease       white     0.791
# 229        low  reversable defect  heart disease       white     2.516
# 230        low       fixed defect  heart disease       white     0.338
# 231       HIGH  reversable defect  heart disease       white    85.169
# 232        low  reversable defect  heart disease       white     9.225
# 233        low       fixed defect  heart disease       white     1.739
# 234        low       fixed defect  heart disease       white     1.305
# 235        low  reversable defect  heart disease       white     1.734
# 236        low  reversable defect  heart disease       white     1.721
# 237        low  reversable defect  heart disease       white     2.195
# 238        low       fixed defect  heart disease       white     3.127
# 239        low  reversable defect  heart disease       white     1.625
# 240        low  reversable defect  heart disease       white     0.360
# 241        low       fixed defect  heart disease       white     3.081
# 242        low             normal  heart disease       white     1.275
# 243        low  reversable defect  heart disease       white     0.574
# 244        low             normal  heart disease       white     0.994
# 245        low  reversable defect  heart disease       white     1.327
# 246        low  reversable defect  heart disease       white    36.806
# 247        low             normal  heart disease       white     3.095
# 248        low  reversable defect  heart disease       white    20.187
# 249        low  reversable defect  heart disease       white    80.756
# 250        low  reversable defect  heart disease       white     3.141
# 251       HIGH  reversable defect  heart disease       white     4.016
# 252       HIGH       fixed defect  heart disease       white     8.774
# 253        low       fixed defect  heart disease       white     3.324
# 254        low       fixed defect  heart disease       white     1.618
# 255        low  reversable defect  heart disease       white     3.552
# 256        low  reversable defect  heart disease       white    13.821
# 257        low  reversable defect  heart disease       white     1.028
# 258        low       fixed defect  heart disease       white     3.576
# 260       HIGH  reversable defect  heart disease       white     1.416
# 261        low       fixed defect  heart disease       white    55.703
# 262        low  reversable defect  heart disease       white     2.089
# 263        low       fixed defect  heart disease       white     2.050
# 264        low       fixed defect  heart disease       white     2.495
# 265        low       fixed defect  heart disease       white     1.562
# 266        low       fixed defect  heart disease       white     4.384
# 267        low       fixed defect  heart disease       white     2.183
# 268        low       fixed defect  heart disease       white     1.808
# 269       HIGH  reversable defect  heart disease       white     5.050
# 270        low  reversable defect  heart disease       white     4.760
# 271        low       fixed defect  heart disease       white     3.050
# 272        low       fixed defect  heart disease       white     2.983
# 273        low  reversable defect  heart disease       white     6.238
# 274        low       fixed defect  heart disease       white     0.792
# 275        low  reversable defect  heart disease       white     2.511
# 276        low  reversable defect  heart disease       white     0.922
# 277        low  reversable defect  heart disease       white     1.399
# 278       HIGH       fixed defect  heart disease       white     7.476
# 279        low       fixed defect  heart disease       white     1.080
# 281       HIGH                NaN  heart disease       white     1.156
# 282       HIGH             normal  heart disease       white     1.096
# 284        low  reversable defect  heart disease       white     2.461
# 285        low  reversable defect  heart disease       white     0.730
# 286        low       fixed defect  heart disease       white     8.345
# 287        low       fixed defect  heart disease       white     0.986
# 288        low  reversable defect  heart disease       white     0.951
# 289        low  reversable defect  heart disease       white     7.976
# 290        low  reversable defect  heart disease       white     1.437
# 291        low             normal  heart disease       white     1.398
# 292       HIGH             normal  heart disease       white     1.966
# 293        low  reversable defect  heart disease       white     0.627
# 295        low  reversable defect  heart disease       white     2.144
# 296        low       fixed defect  heart disease       white     0.239
# 297       HIGH             normal  heart disease       white     4.409
# 298        low  reversable defect  heart disease       white     2.074
# 300       HIGH  reversable defect  heart disease       white    36.971
# 301        low  reversable defect  heart disease       white     1.886
# 302        low       fixed defect  heart disease       white     5.109
#
#      ExterQual_numeric  risk
# 0                    1   383
# 2                   -1   376
# 3                   -1   414
# 4                   -1   517
# 5                    0   340
# 6                    0   447
# 8                   -1   361
# 9                   -1   342
# 10                  -1   399
# 11                  -1   414
# 12                  -1   437
# 13                   0   355
# 14                  -1   445
# 15                   0   377
# 16                  -1   512
# 17                   1   340
# 19                  -1   390
# 20                   0   395
# 23                   0   380
# 25                  -1   464
# 26                  -1   369
# 27                  -1   298
# 28                  -1   574
# 29                   1   349
# 30                  -1   366
# 31                  -1   317
# 32                  -1   407
# 33                   1   425
# 34                  -1   338
# 35                   1   337
# 36                  -1   474
# 37                  -1   397
# 38                  -1   417
# 39                  -1   511
# 40                  -1   450
# 41                   0   425
# 42                   0   356
# 43                   0   407
# 44                  -1   503
# 45                  -1   497
# 46                  -1   415
# 47                  -1   413
# 48                  -1   331
# 49                  -1   394
# 50                  -1   405
# 51                   0   453
# 52                   0   377
# 54                  -1   424
# 55                  -1   359
# 56                  -1   408
# 57                  -1   445
# 58                  -1   356
# 59                  -1   462
# 60                  -1   395
# 61                  -1   465
# 62                   0   376
# 64                  -1   376
# 66                   0   365
# 67                   0   409
# 69                  -1   372
# 70                   0   405
# 71                  -1   381
# 72                  -1   406
# 73                  -1   447
# 75                   0   411
# 76                   0   411
# 77                  -1   385
# 78                  -1   389
# 79                   0   394
# 81                  -1   478
# 82                  -1   478
# 83                   0   476
# 84                   0   387
# 85                   0   724
# 86                  -1   428
# 87                  -1   353
# 88                   0   372
# 89                   0   370
# 90                  -1   430
# 91                  -1   375
# 92                  -1   392
# 93                  -1   447
# 95                  -1   337
# 96                   0   551
# 97                  -1   380
# 98                  -1   477
# 99                  -1   419
# 100                 -1   422
# 101                  1   415
# 102                 -1   374
# 104                 -1   359
# 105                  0   326
# 106                  0   365
# 107                  0   388
# 108                 -1   406
# 109                 -1   413
# 110                 -1   479
# 111                 -1   299
# 112                 -1   446
# 114                 -1   417
# 116                  0   382
# 117                  0   355
# 118                 -1   376
# 119                  0   395
# 120                  0   425
# 121                 -1   453
# 122                 -1   440
# 123                 -1   434
# 126                 -1   347
# 127                 -1   449
# 128                  0   365
# 129                 -1   390
# 130                 -1   364
# 131                  0   433
# 135                 -1   432
# 136                 -1   274
# 137                 -1   348
# 138                  0   327
# 139                  0   368
# 140                 -1   452
# 143                 -1   365
# 144                  0   313
# 145                 -1   388
# 146                  0   391
# 147                 -1   411
# 150                 -1   366
# 151                  0   274
# 152                  0   382
# 153                  0   430
# 155                  0   328
# 156                 -1   432
# 158                  0   364
# 159                 -1   384
# 160                  1   409
# 161                 -1   508
# 165                  0   394
# 166                  0   358
# 167                  1   428
# 168                  0   401
# 169                  1   358
# 170                  0   398
# 171                  1   397
# 172                  0   444
# 173                 -1   397
# 174                  0   338
# 175                  0   281
# 176                 -1   390
# 177                 -1   493
# 178                  0   297
# 179                  0   388
# 180                  0   485
# 181                  0   339
# 182                 -1   499
# 183                  0   395
# 184                  0   371
# 185                 -1   443
# 186                 -1   397
# 187                  0   375
# 188                  0   396
# 189                 -1   330
# 190                  0   447
# 191                  0   347
# 192                  0   301
# 193                  0   424
# 194                  0   340
# 195                  1   466
# 196                  0   378
# 197                  0   417
# 198                  0   366
# 199                 -1   406
# 200                 -1   374
# 201                  0   399
# 202                 -1   381
# 203                  0   424
# 204                  1   309
# 205                 -1   416
# 206                  0   381
# 207                  0   415
# 208                  0   327
# 209                 -1   339
# 210                  0   379
# 211                  0   400
# 213                  0   453
# 214                  0   393
# 215                  0   477
# 216                  0   360
# 217                 -1   462
# 218                  0   381
# 219                 -1   406
# 220                  0   561
# 221                  1   328
# 222                  0   456
# 223                  1   421
# 224                  0   365
# 225                  1   299
# 226                  0   384
# 228                  0   447
# 229                  0   440
# 230                 -1   395
# 231                  0   413
# 232                  0   434
# 233                  1   342
# 234                  0   431
# 235                 -1   472
# 236                 -1   471
# 237                  0   463
# 238                 -1   466
# 239                 -1   438
# 240                  0   381
# 241                  0   392
# 242                  0   344
# 243                  0   362
# 244                  0   289
# 245                  0   440
# 246                  0   559
# 247                  0   366
# 248                 -1   478
# 249                  0   400
# 250                  0   420
# 251                  0   390
# 252                  0   400
# 253                  0   424
# 254                 -1   398
# 255                  0   456
# 256                  0   389
# 257                  0   326
# 258                  0   398
# 260                  0   393
# 261                 -1   390
# 262                  0   377
# 263                  0   438
# 264                  0   314
# 265                 -1   344
# 266                  0   444
# 267                 -1   275
# 268                  0   402
# 269                  1   386
# 270                 -1   393
# 271                  0   379
# 272                  0   308
# 273                 -1   390
# 274                  0   393
# 275                 -1   380
# 276                  0   323
# 277                 -1   402
# 278                 -1   471
# 279                  0   291
# 281                  0   360
# 282                  0   352
# 284                 -1   345
# 285                  0   431
# 286                 -1   366
# 287                 -1   396
# 288                  0   478
# 289                  0   335
# 290                 -1   364
# 291                  1   458
# 292                  0   371
# 293                  0   362
# 295                 -1   331
# 296                  0   333
# 297                  0   266
# 298                  0   364
# 300                  0   334
# 301                  0   246
# 302                  0   410

# %%
# same query as bove but with describe()
df.query("age > 45 | 	ca>0 |RESTECG_string=='normal'",inplace=False).describe()
# Out:
#               age          ca    trestbps        chol     thalach     oldpeak  \
# count  266.000000  266.000000  266.000000  266.000000  266.000000  266.000000
# mean    56.263158    0.755639  132.669173  249.860902  147.372180    1.093609
# std      7.947369    0.961753   17.910563   52.147608   22.566142    1.171935
# min     29.000000    0.000000   94.000000  126.000000   71.000000    0.000000
# 25%     51.000000    0.000000  120.000000  212.250000  132.000000    0.000000
# 50%     57.000000    0.000000  130.000000  244.500000  151.000000    0.800000
# 75%     62.000000    1.000000  140.000000  277.750000  163.000000    1.800000
# max     77.000000    3.000000  200.000000  564.000000  202.000000    6.200000
#
#          incident  ExterQual_numeric        risk
# count  266.000000         266.000000  266.000000
# mean     5.536241          -0.383459  397.233083
# std     10.814664           0.610868   57.861825
# min      0.038000          -1.000000  246.000000
# 25%      1.403000          -1.000000  364.000000
# 50%      2.394500           0.000000  393.500000
# 75%      4.457500           0.000000  430.000000
# max     85.169000           1.000000  724.000000

# %%
df.query("ca != 0 and SEX_string > 'female' ").describe()
# Out:
#              age         ca    trestbps        chol     thalach    oldpeak  \
# count  91.000000  91.000000   91.000000   91.000000   91.000000  91.000000
# mean   57.835165   1.626374  130.659341  246.395604  139.318681   1.393407
# std     6.873886   0.769536   16.587291   44.713130   23.390824   1.168646
# min    42.000000   1.000000   94.000000  126.000000   88.000000   0.000000
# 25%    54.000000   1.000000  120.000000  217.000000  124.500000   0.200000
# 50%    58.000000   1.000000  130.000000  248.000000  142.000000   1.200000
# 75%    62.000000   2.000000  140.000000  279.000000  159.000000   2.200000
# max    77.000000   3.000000  192.000000  353.000000  195.000000   4.400000
#
#         incident  ExterQual_numeric        risk
# count  91.000000          91.000000   91.000000
# mean    6.190571          -0.329670  385.714286
# std    13.964996           0.538619   49.679257
# min     0.355000          -1.000000  246.000000
# 25%     1.172500          -1.000000  360.500000
# 50%     2.089000           0.000000  389.000000
# 75%     3.711000           0.000000  418.000000
# max    85.169000           1.000000  485.000000

# %%
#This shows just the descriptive statistics ( with .describe() ) for two variables (after ".filter") for data that matches the query
print(df.query("ca != 0").filter(['age', 'FBS_string']).describe())
# Out:
#               age
# count  123.000000
# mean    58.585366
# std      7.061703
# min     41.000000
# 25%     54.000000
# 50%     58.000000
# 75%     63.000000
# max     77.000000

# %%
# It is possible to define a new dataframe with the equals sign with the query criteria
new_criteria = 1.3
df_filter=df.query("oldpeak > @new_criteria")
# print(df_filter.head)
print(df_filter.shape)
# There are benefits to having a new dataframe but there are challenges too.
# Can you think of some pros and cons?
# Out:
# (103, 17)

# %%
# Descriptive Statistics for query results
# https://www.youtube.com/watch?v=mBZwYUaIRfY
df_filter.describe()
# Out:
#               age          ca    trestbps        chol     thalach     oldpeak  \
# count  103.000000  103.000000  103.000000  103.000000  103.000000  103.000000
# mean    56.650485    1.000000  134.495146  247.796117  139.941748    2.376699
# std      8.672368    1.066422   17.360014   59.928447   21.707424    0.941443
# min     35.000000    0.000000  104.000000  149.000000   95.000000    1.400000
# 25%     52.000000    0.000000  120.000000  209.500000  125.000000    1.600000
# 50%     58.000000    1.000000  132.000000  239.000000  141.000000    2.000000
# 75%     63.000000    2.000000  143.000000  282.000000  157.000000    2.850000
# max     71.000000    3.000000  200.000000  564.000000  187.000000    6.200000
#
#          incident  ExterQual_numeric        risk
# count  103.000000         103.000000  103.000000
# mean     5.943825          -0.029126  387.737864
# std     11.890539           0.585048   63.004351
# min      0.310000          -1.000000  274.000000
# 25%      1.484000           0.000000  344.500000
# 50%      2.516000           0.000000  381.000000
# 75%      4.293000           0.000000  419.000000
# max     80.756000           1.000000  724.000000

# %%
# Useing a variable to define criteria
new_criteria=1.4
# use the "@" to designate the variable in the string query
df.query("oldpeak > @new_criteria")
# Out:
#      age  ca  trestbps  chol  thalach  oldpeak SEX_string  \
# 0     63   0       145   233      150      2.3       male
# 1     37   0       130   250      187      3.5       male
# 9     57   0       150   168      174      1.6       male
# 13    64   0       110   211      144      1.8       male
# 15    50   0       120   219      158      1.6     female
# 17    66   0       150   226      114      2.6     female
# 18    43   0       150   247      171      1.5       male
# 19    69   2       140   239      151      1.8     female
# 26    59   0       150   212      157      1.6       male
# 37    54   0       150   232      165      1.6       male
# 40    51   1       140   308      142      1.5     female
# 42    45   0       104   208      148      3.0       male
# 52    62   3       130   231      146      1.8       male
# 76    51   0       125   245      166      2.4       male
# 85    67   0       115   564      160      1.6     female
# 88    54   0       110   214      158      1.6     female
# 98    43   1       130   315      162      1.9       male
# 101   59   0       178   270      145      4.2       male
# 105   68   0       120   211      115      1.5     female
# 116   41   0       130   214      168      2.0       male
# 117   56   0       120   193      162      1.9       male
# 120   64   2       130   303      122      2.0     female
# 138   57   0       110   201      126      1.5       male
# 150   66   0       160   228      138      2.3       male
# 151   71   0       112   149      125      1.6     female
# 165   67   3       160   286      108      1.5       male
# 166   67   2       120   229      129      2.6       male
# 167   62   2       140   268      160      3.6     female
# 169   53   0       140   203      155      3.1       male
# 172   58   0       120   284      160      1.8       male
# 173   58   2       132   224      173      3.2       male
# 174   60   2       130   206      132      2.4       male
# 175   40   0       110   167      114      2.0       male
# 178   43   0       120   177      120      2.5       male
# 183   58   1       112   230      165      2.5       male
# 184   50   0       150   243      128      2.6       male
# 187   54   1       124   266      109      2.2       male
# 191   58   3       128   216      131      2.2       male
# 193   60   2       145   282      142      2.8       male
# 194   60   0       140   185      155      3.0       male
# 195   59   0       170   326      140      3.4       male
# 196   46   0       150   231      147      3.6       male
# 198   62   2       120   267       99      1.8       male
# 201   60   1       125   258      141      2.8       male
# 203   68   0       180   274      150      1.6       male
# 204   62   3       160   164      145      6.2     female
# 207   60   2       150   258      157      2.6     female
# 208   49   3       120   188      139      2.0       male
# 211   61   1       120   260      140      3.6       male
# 215   43   0       132   341      136      3.0     female
# 217   63   3       130   330      132      1.8       male
# 218   65   1       135   254      127      2.8       male
# 220   63   3       150   407      154      4.0     female
# 221   55   0       140   217      111      5.6       male
# 223   56   2       200   288      133      4.0     female
# 224   54   1       110   239      126      2.8       male
# 225   70   0       145   174      125      2.6       male
# 227   35   0       120   198      130      1.6       male
# 229   64   0       125   309      131      1.8       male
# 233   64   1       120   246       96      2.2       male
# 234   70   3       130   322      109      2.4       male
# 235   51   0       140   299      173      1.6       male
# 240   70   1       160   269      112      2.9       male
# 242   64   2       145   212      132      2.0       male
# 244   56   1       132   184      105      2.1       male
# 246   56   2       134   409      150      1.9     female
# 249   69   3       140   254      146      2.0       male
# 250   51   3       140   298      122      4.2       male
# 252   62   3       138   294      106      1.9     female
# 256   58   2       128   259      130      3.0       male
# 259   38   0       120   231      182      3.8       male
# 262   53   2       123   282       95      2.0       male
# 263   63   2       108   269      169      1.8     female
# 266   55   0       180   327      117      3.4     female
# 268   54   2       122   286      116      3.2       male
# 269   56   0       130   283      103      1.6       male
# 271   61   2       134   234      145      2.6       male
# 276   58   1       146   218      105      2.0       male
# 279   61   1       138   166      125      3.6       male
# 280   42   0       136   315      125      1.8       male
# 282   59   1       126   218      134      2.2       male
# 284   61   1       140   207      138      1.9       male
# 285   46   2       140   311      120      1.8       male
# 288   57   1       110   335      143      3.0       male
# 289   55   1       128   205      130      2.0     female
# 291   58   3       114   318      140      4.4       male
# 292   58   2       170   225      146      2.8     female
# 294   44   0       120   169      144      2.8       male
# 295   63   2       140   187      144      4.0       male
# 300   68   2       144   193      141      3.4       male
#
#                CP_string                RESTECG_string EXANG_string  \
# 0    asymptomatic angina                        normal           no
# 1             non-angina         ST-T wave abnormality           no
# 9             non-angina         ST-T wave abnormality           no
# 13   asymptomatic angina                        normal          yes
# 15            non-angina         ST-T wave abnormality           no
# 17   asymptomatic angina         ST-T wave abnormality           no
# 18        typical angina         ST-T wave abnormality           no
# 19   asymptomatic angina         ST-T wave abnormality           no
# 26            non-angina         ST-T wave abnormality           no
# 37            non-angina                        normal           no
# 40            non-angina                        normal           no
# 42        typical angina                        normal          yes
# 52            non-angina         ST-T wave abnormality           no
# 76            non-angina                        normal           no
# 85            non-angina                        normal           no
# 88            non-angina         ST-T wave abnormality           no
# 98            non-angina         ST-T wave abnormality           no
# 101  asymptomatic angina                        normal           no
# 105           non-angina                        normal           no
# 116           non-angina                        normal           no
# 117  asymptomatic angina                        normal           no
# 120       typical angina         ST-T wave abnormality           no
# 138       typical angina         ST-T wave abnormality          yes
# 150       typical angina                        normal           no
# 151       typical angina         ST-T wave abnormality           no
# 165       typical angina                        normal          yes
# 166       typical angina                        normal          yes
# 167       typical angina                        normal           no
# 169       typical angina                        normal          yes
# 172      atypical angina                        normal           no
# 173           non-angina                        normal           no
# 174       typical angina                        normal          yes
# 175       typical angina                        normal          yes
# 178       typical angina                        normal          yes
# 183           non-angina                        normal           no
# 184       typical angina                        normal           no
# 187       typical angina                        normal          yes
# 191       typical angina                        normal          yes
# 193       typical angina                        normal          yes
# 194           non-angina                        normal           no
# 195       typical angina                        normal          yes
# 196           non-angina         ST-T wave abnormality           no
# 198       typical angina         ST-T wave abnormality          yes
# 201       typical angina                        normal          yes
# 203           non-angina                        normal          yes
# 204       typical angina                        normal           no
# 207       typical angina                        normal           no
# 208           non-angina         ST-T wave abnormality           no
# 211       typical angina         ST-T wave abnormality          yes
# 215       typical angina                        normal          yes
# 217       typical angina                        normal          yes
# 218       typical angina                        normal           no
# 220       typical angina                        normal           no
# 221       typical angina         ST-T wave abnormality          yes
# 223       typical angina                        normal          yes
# 224       typical angina         ST-T wave abnormality          yes
# 225       typical angina         ST-T wave abnormality          yes
# 227       typical angina         ST-T wave abnormality          yes
# 229           non-angina         ST-T wave abnormality          yes
# 233       typical angina                        normal          yes
# 234       typical angina                        normal           no
# 235       typical angina         ST-T wave abnormality          yes
# 240           non-angina         ST-T wave abnormality          yes
# 242       typical angina                        normal           no
# 244       typical angina                        normal          yes
# 246       typical angina                        normal          yes
# 249           non-angina                        normal           no
# 250       typical angina         ST-T wave abnormality          yes
# 252       typical angina         ST-T wave abnormality           no
# 256       typical angina                        normal          yes
# 259  asymptomatic angina         ST-T wave abnormality          yes
# 262       typical angina         ST-T wave abnormality          yes
# 263       typical angina         ST-T wave abnormality          yes
# 266       typical angina  left ventricular hypertrophy          yes
# 268       typical angina                        normal          yes
# 269       typical angina                        normal          yes
# 271  asymptomatic angina         ST-T wave abnormality           no
# 276       typical angina         ST-T wave abnormality           no
# 279       typical angina                        normal          yes
# 280       typical angina         ST-T wave abnormality          yes
# 282           non-angina         ST-T wave abnormality           no
# 284       typical angina                        normal          yes
# 285       typical angina         ST-T wave abnormality          yes
# 288       typical angina         ST-T wave abnormality          yes
# 289       typical angina  left ventricular hypertrophy          yes
# 291       typical angina  left ventricular hypertrophy           no
# 292       typical angina                        normal          yes
# 294       typical angina         ST-T wave abnormality          yes
# 295       typical angina                        normal          yes
# 300       typical angina         ST-T wave abnormality           no
#
#     FBS_string        THAL_string  TARGET_string Race_String  incident  \
# 0         HIGH             normal   asymptomatic       white     3.803
# 1          low       fixed defect   asymptomatic       black     2.815
# 9          low       fixed defect   asymptomatic       asian     3.670
# 13         low       fixed defect   asymptomatic       asian    23.084
# 15         low       fixed defect   asymptomatic       black     1.986
# 17         low       fixed defect   asymptomatic       white     7.887
# 18         low       fixed defect   asymptomatic       asian     3.305
# 19         low       fixed defect   asymptomatic       black     3.403
# 26        HIGH       fixed defect   asymptomatic       black     2.934
# 37         low  reversable defect   asymptomatic       black    19.776
# 40         low       fixed defect   asymptomatic       black     3.035
# 42         low       fixed defect   asymptomatic       asian     3.265
# 52         low  reversable defect   asymptomatic       asian     2.075
# 76        HIGH       fixed defect   asymptomatic       black     0.480
# 85         low  reversable defect   asymptomatic       asian    11.587
# 88         low       fixed defect   asymptomatic       white     6.805
# 98         low       fixed defect   asymptomatic       asian     5.760
# 101        low  reversable defect   asymptomatic       black     0.622
# 105        low       fixed defect   asymptomatic       black     3.524
# 116        low       fixed defect   asymptomatic       white     0.760
# 117        low  reversable defect   asymptomatic       asian     0.824
# 120        low       fixed defect   asymptomatic       asian     1.911
# 138        low             normal   asymptomatic       black     3.557
# 150        low             normal   asymptomatic       white     7.853
# 151        low       fixed defect   asymptomatic       asian     4.981
# 165        low       fixed defect  heart disease       white     1.202
# 166        low  reversable defect  heart disease       white    25.727
# 167        low       fixed defect  heart disease       white     3.427
# 169       HIGH  reversable defect  heart disease       white     1.319
# 172        low       fixed defect  heart disease       white     7.077
# 173        low  reversable defect  heart disease       white     2.774
# 174        low  reversable defect  heart disease       white     2.565
# 175        low  reversable defect  heart disease       white     1.901
# 178        low  reversable defect  heart disease       white     5.429
# 183        low  reversable defect  heart disease       white    17.053
# 184        low  reversable defect  heart disease       white     4.271
# 187        low  reversable defect  heart disease       white     1.771
# 191        low  reversable defect  heart disease       white     1.585
# 193        low  reversable defect  heart disease       white     2.341
# 194        low       fixed defect  heart disease       white     3.067
# 195        low  reversable defect  heart disease       white     1.986
# 196        low       fixed defect  heart disease       white    10.771
# 198        low  reversable defect  heart disease       white     3.392
# 201        low  reversable defect  heart disease       white     1.590
# 203       HIGH  reversable defect  heart disease       white     1.837
# 204        low  reversable defect  heart disease       white     2.178
# 207        low  reversable defect  heart disease       white     1.550
# 208        low  reversable defect  heart disease       white     2.620
# 211        low  reversable defect  heart disease       white     1.815
# 215       HIGH  reversable defect  heart disease       white     2.594
# 217       HIGH  reversable defect  heart disease       white     4.022
# 218        low  reversable defect  heart disease       white     3.512
# 220        low  reversable defect  heart disease       white     4.315
# 221        low  reversable defect  heart disease       white    72.143
# 223       HIGH  reversable defect  heart disease       white     0.310
# 224        low  reversable defect  heart disease       white     0.887
# 225        low  reversable defect  heart disease       white     1.101
# 227        low  reversable defect  heart disease       white     1.579
# 229        low  reversable defect  heart disease       white     2.516
# 233        low       fixed defect  heart disease       white     1.739
# 234        low       fixed defect  heart disease       white     1.305
# 235        low  reversable defect  heart disease       white     1.734
# 240        low  reversable defect  heart disease       white     0.360
# 242        low             normal  heart disease       white     1.275
# 244        low             normal  heart disease       white     0.994
# 246        low  reversable defect  heart disease       white    36.806
# 249        low  reversable defect  heart disease       white    80.756
# 250        low  reversable defect  heart disease       white     3.141
# 252       HIGH       fixed defect  heart disease       white     8.774
# 256        low  reversable defect  heart disease       white    13.821
# 259        low  reversable defect  heart disease       white    10.978
# 262        low  reversable defect  heart disease       white     2.089
# 263        low       fixed defect  heart disease       white     2.050
# 266        low       fixed defect  heart disease       white     4.384
# 268        low       fixed defect  heart disease       white     1.808
# 269       HIGH  reversable defect  heart disease       white     5.050
# 271        low       fixed defect  heart disease       white     3.050
# 276        low  reversable defect  heart disease       white     0.922
# 279        low       fixed defect  heart disease       white     1.080
# 280        low             normal  heart disease       white    15.499
# 282       HIGH             normal  heart disease       white     1.096
# 284        low  reversable defect  heart disease       white     2.461
# 285        low  reversable defect  heart disease       white     0.730
# 288        low  reversable defect  heart disease       white     0.951
# 289        low  reversable defect  heart disease       white     7.976
# 291        low             normal  heart disease       white     1.398
# 292       HIGH             normal  heart disease       white     1.966
# 294        low             normal  heart disease       white     2.833
# 295        low  reversable defect  heart disease       white     2.144
# 300       HIGH  reversable defect  heart disease       white    36.971
#
#      ExterQual_numeric  risk
# 0                    1   383
# 1                    1   437
# 9                   -1   342
# 13                   0   355
# 15                   0   377
# 17                   1   340
# 18                  -1   418
# 19                  -1   390
# 26                  -1   369
# 37                  -1   397
# 40                  -1   450
# 42                   0   356
# 52                   0   377
# 76                   0   411
# 85                   0   724
# 88                   0   372
# 98                  -1   477
# 101                  1   415
# 105                  0   326
# 116                  0   382
# 117                  0   355
# 120                  0   425
# 138                  0   327
# 150                 -1   366
# 151                  0   274
# 165                  0   394
# 166                  0   358
# 167                  1   428
# 169                  1   358
# 172                  0   444
# 173                 -1   397
# 174                  0   338
# 175                  0   281
# 178                  0   297
# 183                  0   395
# 184                  0   371
# 187                  0   375
# 191                  0   347
# 193                  0   424
# 194                  0   340
# 195                  1   466
# 196                  0   378
# 198                  0   366
# 201                  0   399
# 203                  0   424
# 204                  1   309
# 207                  0   415
# 208                  0   327
# 211                  0   400
# 215                  0   477
# 217                 -1   462
# 218                  0   381
# 220                  0   561
# 221                  1   328
# 223                  1   421
# 224                  0   365
# 225                  1   299
# 227                  0   328
# 229                  0   440
# 233                  1   342
# 234                  0   431
# 235                 -1   472
# 240                  0   381
# 242                  0   344
# 244                  0   289
# 246                  0   559
# 249                  0   400
# 250                  0   420
# 252                  0   400
# 256                  0   389
# 259                  0   413
# 262                  0   377
# 263                  0   438
# 266                  0   444
# 268                  0   402
# 269                  1   386
# 271                  0   379
# 276                  0   323
# 279                  0   291
# 280                  0   440
# 282                  0   352
# 284                 -1   345
# 285                  0   431
# 288                  0   478
# 289                  0   335
# 291                  1   458
# 292                  0   371
# 294                  1   313
# 295                 -1   331
# 300                  0   334

# %% [markdown]
# ## EDA with filter in Pandas

# %%
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.filter.html?highlight=filter#pandas.DataFrame.filter
# filter string (object) data if it has a certain string in it.
df['THAL_string'].str.contains('defect')
#returns a boolean Ture or False
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4       True
# 5      False
# 6       True
# 7       True
# 8       True
# 9       True
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
# 21      True
# 22      True
# 23      True
# 24      True
# 25      True
# 26      True
# 27      True
# 28      True
# 29      True
# 30      True
# 31      True
# 32      True
# 33      True
# 34      True
# 35      True
# 36      True
# 37      True
# 38      True
# 39      True
# 40      True
# 41      True
# 42      True
# 43      True
# 44      True
# 45      True
# 46      True
# 47      True
# 48       NaN
# 49      True
# 50      True
# 51      True
# 52      True
# 53      True
# 54      True
# 55      True
# 56      True
# 57      True
# 58      True
# 59      True
# 60      True
# 61      True
# 62     False
# 63     False
# 64      True
# 65      True
# 66      True
# 67      True
# 68      True
# 69      True
# 70      True
# 71      True
# 72      True
# 73      True
# 74      True
# 75      True
# 76      True
# 77      True
# 78      True
# 79      True
# 80      True
# 81      True
# 82      True
# 83      True
# 84      True
# 85      True
# 86      True
# 87      True
# 88      True
# 89      True
# 90      True
# 91      True
# 92      True
# 93      True
# 94      True
# 95      True
# 96      True
# 97      True
# 98      True
# 99      True
# 100     True
# 101     True
# 102     True
# 103     True
# 104     True
# 105     True
# 106     True
# 107     True
# 108     True
# 109     True
# 110     True
# 111     True
# 112     True
# 113     True
# 114     True
# 115     True
# 116     True
# 117     True
# 118     True
# 119     True
# 120     True
# 121     True
# 122     True
# 123     True
# 124     True
# 125     True
# 126     True
# 127     True
# 128     True
# 129     True
# 130     True
# 131     True
# 132     True
# 133     True
# 134     True
# 135     True
# 136     True
# 137     True
# 138    False
# 139     True
# 140     True
# 141     True
# 142     True
# 143     True
# 144     True
# 145     True
# 146     True
# 147     True
# 148     True
# 149     True
# 150    False
# 151     True
# 152     True
# 153     True
# 154     True
# 155     True
# 156     True
# 157     True
# 158     True
# 159     True
# 160     True
# 161     True
# 162     True
# 163     True
# 164     True
# 165     True
# 166     True
# 167     True
# 168     True
# 169     True
# 170    False
# 171     True
# 172     True
# 173     True
# 174     True
# 175     True
# 176     True
# 177     True
# 178     True
# 179    False
# 180     True
# 181     True
# 182     True
# 183     True
# 184     True
# 185     True
# 186     True
# 187     True
# 188     True
# 189     True
# 190     True
# 191     True
# 192     True
# 193     True
# 194     True
# 195     True
# 196     True
# 197     True
# 198     True
# 199    False
# 200     True
# 201     True
# 202     True
# 203     True
# 204     True
# 205     True
# 206     True
# 207     True
# 208     True
# 209     True
# 210     True
# 211     True
# 212     True
# 213     True
# 214     True
# 215     True
# 216     True
# 217     True
# 218     True
# 219     True
# 220     True
# 221     True
# 222     True
# 223     True
# 224     True
# 225     True
# 226     True
# 227     True
# 228     True
# 229     True
# 230     True
# 231     True
# 232     True
# 233     True
# 234     True
# 235     True
# 236     True
# 237     True
# 238     True
# 239     True
# 240     True
# 241     True
# 242    False
# 243     True
# 244    False
# 245     True
# 246     True
# 247    False
# 248     True
# 249     True
# 250     True
# 251     True
# 252     True
# 253     True
# 254     True
# 255     True
# 256     True
# 257     True
# 258     True
# 259     True
# 260     True
# 261     True
# 262     True
# 263     True
# 264     True
# 265     True
# 266     True
# 267     True
# 268     True
# 269     True
# 270     True
# 271     True
# 272     True
# 273     True
# 274     True
# 275     True
# 276     True
# 277     True
# 278     True
# 279     True
# 280    False
# 281      NaN
# 282    False
# 283     True
# 284     True
# 285     True
# 286     True
# 287     True
# 288     True
# 289     True
# 290     True
# 291    False
# 292    False
# 293     True
# 294    False
# 295     True
# 296     True
# 297    False
# 298     True
# 299     True
# 300     True
# 301     True
# 302     True
# Name: THAL_string, dtype: object

# %% [markdown]
# ## EDA loc & iloc in Pandas

# %%
# loc selects rows and columns with specific labels
# iloc selcts rows and columns by index
# to find particular rows , colums
df.iloc[0:12,10:12]
#the iloc will return the first 13 items from the filtered df
#EXANG_string	FBS_string are columns 10 & 11 (the range is exclusive on the high side meaning that 12 is not include)
#if you want column 12, update to "10:13"
# Out:
#    FBS_string        THAL_string
# 0        HIGH             normal
# 1         low       fixed defect
# 2         low       fixed defect
# 3         low       fixed defect
# 4         low       fixed defect
# 5         low             normal
# 6         low       fixed defect
# 7         low  reversable defect
# 8        HIGH  reversable defect
# 9         low       fixed defect
# 10        low       fixed defect
# 11        low       fixed defect

# %%
#loc for the same
df.loc[:12,['EXANG_string','FBS_string']]
#the loc will return the first items in index 0-12 from the filtered df
# remember, df_filter has rows that were filtered away.
# the loc and iloc would be the same on the orginal df
# Out:
#    EXANG_string FBS_string
# 0            no       HIGH
# 1            no        low
# 2            no        low
# 3            no        low
# 4           yes        low
# 5            no        low
# 6            no        low
# 7            no        low
# 8            no       HIGH
# 9            no        low
# 10           no        low
# 11           no        low
# 12           no        low

# %%
df.loc[:12,['EXANG_string','FBS_string']]
# Out:
#    EXANG_string FBS_string
# 0            no       HIGH
# 1            no        low
# 2            no        low
# 3            no        low
# 4           yes        low
# 5            no        low
# 6            no        low
# 7            no        low
# 8            no       HIGH
# 9            no        low
# 10           no        low
# 11           no        low
# 12           no        low

# %%
df.iloc[0:12,10:12]
# Out:
#    FBS_string        THAL_string
# 0        HIGH             normal
# 1         low       fixed defect
# 2         low       fixed defect
# 3         low       fixed defect
# 4         low       fixed defect
# 5         low             normal
# 6         low       fixed defect
# 7         low  reversable defect
# 8        HIGH  reversable defect
# 9         low       fixed defect
# 10        low       fixed defect
# 11        low       fixed defect

# %%
# Here we are use iloc to look through the filtered data frame
df_filter.iloc[0:12] #only looking through index 0-12 (the filtered data only has a few outputs for this range)
# NOTE in the loc statement, the [0:12] above is the same as [:12] used in the next cell below
# Out:
#     age  ca  trestbps  chol  thalach  oldpeak SEX_string            CP_string  \
# 0    63   0       145   233      150      2.3       male  asymptomatic angina
# 1    37   0       130   250      187      3.5       male           non-angina
# 2    41   0       130   204      172      1.4     female      atypical angina
# 9    57   0       150   168      174      1.6       male           non-angina
# 13   64   0       110   211      144      1.8       male  asymptomatic angina
# 15   50   0       120   219      158      1.6     female           non-angina
# 17   66   0       150   226      114      2.6     female  asymptomatic angina
# 18   43   0       150   247      171      1.5       male       typical angina
# 19   69   2       140   239      151      1.8     female  asymptomatic angina
# 24   40   0       140   199      178      1.4       male  asymptomatic angina
# 26   59   0       150   212      157      1.6       male           non-angina
# 34   51   1       125   213      125      1.4       male  asymptomatic angina
#
#            RESTECG_string EXANG_string FBS_string        THAL_string  \
# 0                  normal           no       HIGH             normal
# 1   ST-T wave abnormality           no        low       fixed defect
# 2                  normal           no        low       fixed defect
# 9   ST-T wave abnormality           no        low       fixed defect
# 13                 normal          yes        low       fixed defect
# 15  ST-T wave abnormality           no        low       fixed defect
# 17  ST-T wave abnormality           no        low       fixed defect
# 18  ST-T wave abnormality           no        low       fixed defect
# 19  ST-T wave abnormality           no        low       fixed defect
# 24  ST-T wave abnormality          yes        low  reversable defect
# 26  ST-T wave abnormality           no       HIGH       fixed defect
# 34                 normal          yes        low       fixed defect
#
#    TARGET_string Race_String  incident  ExterQual_numeric  risk
# 0   asymptomatic       white     3.803                  1   383
# 1   asymptomatic       black     2.815                  1   437
# 2   asymptomatic       white     1.854                 -1   376
# 9   asymptomatic       asian     3.670                 -1   342
# 13  asymptomatic       asian    23.084                  0   355
# 15  asymptomatic       black     1.986                  0   377
# 17  asymptomatic       white     7.887                  1   340
# 18  asymptomatic       asian     3.305                 -1   418
# 19  asymptomatic       black     3.403                 -1   390
# 24  asymptomatic       white     1.008                 -1   377
# 26  asymptomatic       black     2.934                 -1   369
# 34  asymptomatic       black     1.143                 -1   338

# %%
#the Full dataframe (unfiltered) has all the values in indices 1-12
df.iloc[:12]
# Out:
#     age  ca  trestbps  chol  thalach  oldpeak SEX_string            CP_string  \
# 0    63   0       145   233      150      2.3       male  asymptomatic angina
# 1    37   0       130   250      187      3.5       male           non-angina
# 2    41   0       130   204      172      1.4     female      atypical angina
# 3    56   0       120   236      178      0.8       male      atypical angina
# 4    57   0       120   354      163      0.6     female       typical angina
# 5    57   0       140   192      148      0.4       male       typical angina
# 6    56   0       140   294      153      1.3     female      atypical angina
# 7    44   0       120   263      173      0.0       male      atypical angina
# 8    52   0       172   199      162      0.5       male           non-angina
# 9    57   0       150   168      174      1.6       male           non-angina
# 10   54   0       140   239      160      1.2       male       typical angina
# 11   48   0       130   275      139      0.2     female           non-angina
#
#            RESTECG_string EXANG_string FBS_string        THAL_string  \
# 0                  normal           no       HIGH             normal
# 1   ST-T wave abnormality           no        low       fixed defect
# 2                  normal           no        low       fixed defect
# 3   ST-T wave abnormality           no        low       fixed defect
# 4   ST-T wave abnormality          yes        low       fixed defect
# 5   ST-T wave abnormality           no        low             normal
# 6                  normal           no        low       fixed defect
# 7   ST-T wave abnormality           no        low  reversable defect
# 8   ST-T wave abnormality           no       HIGH  reversable defect
# 9   ST-T wave abnormality           no        low       fixed defect
# 10  ST-T wave abnormality           no        low       fixed defect
# 11  ST-T wave abnormality           no        low       fixed defect
#
#    TARGET_string Race_String  incident  ExterQual_numeric  risk
# 0   asymptomatic       white     3.803                  1   383
# 1   asymptomatic       black     2.815                  1   437
# 2   asymptomatic       white     1.854                 -1   376
# 3   asymptomatic       black    23.172                 -1   414
# 4   asymptomatic       white    13.378                 -1   517
# 5   asymptomatic       black     6.235                  0   340
# 6   asymptomatic       white     2.263                  0   447
# 7   asymptomatic       white    36.234                 -1   436
# 8   asymptomatic       asian     2.312                 -1   361
# 9   asymptomatic       asian     3.670                 -1   342
# 10  asymptomatic       asian     0.502                 -1   399
# 11  asymptomatic       black     5.262                 -1   414

# %%
# basic feature engineering, adding a new variable
df["year_born"]= 2022-df["age"]
print(df["year_born"].head(10))
# Out:
# 0    1959
# 1    1985
# 2    1981
# 3    1966
# 4    1965
# 5    1965
# 6    1966
# 7    1978
# 8    1970
# 9    1965
# Name: year_born, dtype: int64

# %%
# TWO ways to build dataframes based on two ways to search data loc and Query()
oldMen_query = df.query("SEX_string == 'male' and age > 65", inplace=False)
oldMen_loc = df.loc[(df.SEX_string == 'male') & (df.age > 65 )]

# Test the output
print(oldMen_query.shape)
print(oldMen_loc.shape)
# Out:
# (20, 18)
# (20, 18)

# %%
#should be the same numbers for the oldMen_loc and oldMen_query
oldMen_loc.describe()
# Out:
#              age         ca    trestbps        chol    thalach    oldpeak  \
# count  20.000000  20.000000   20.000000   20.000000   20.00000  20.000000
# mean   68.250000   1.350000  139.350000  252.550000  132.85000   1.290000
# std     2.510504   1.225819   21.337575   39.318504   21.91917   1.117752
# min    66.000000   0.000000  100.000000  174.000000   71.00000   0.000000
# 25%    67.000000   0.000000  120.000000  228.750000  123.75000   0.175000
# 50%    67.500000   1.000000  142.000000  250.000000  135.00000   1.000000
# 75%    69.250000   2.250000  160.000000  279.250000  150.00000   2.325000
# max    77.000000   3.000000  180.000000  322.000000  163.00000   3.400000
#
#         incident  ExterQual_numeric        risk    year_born
# count  20.000000          20.000000   20.000000    20.000000
# mean    9.343300          -0.200000  385.400000  1953.750000
# std    19.203046           0.523148   45.613248     2.510504
# min     0.360000          -1.000000  299.000000  1945.000000
# 25%     1.176750          -0.250000  361.000000  1952.750000
# 50%     2.307000           0.000000  384.500000  1954.500000
# 75%     4.456250           0.000000  424.000000  1955.000000
# max    80.756000           1.000000  466.000000  1956.000000

# %%
oldMen_query.describe()
# Out:
#              age         ca    trestbps        chol    thalach    oldpeak  \
# count  20.000000  20.000000   20.000000   20.000000   20.00000  20.000000
# mean   68.250000   1.350000  139.350000  252.550000  132.85000   1.290000
# std     2.510504   1.225819   21.337575   39.318504   21.91917   1.117752
# min    66.000000   0.000000  100.000000  174.000000   71.00000   0.000000
# 25%    67.000000   0.000000  120.000000  228.750000  123.75000   0.175000
# 50%    67.500000   1.000000  142.000000  250.000000  135.00000   1.000000
# 75%    69.250000   2.250000  160.000000  279.250000  150.00000   2.325000
# max    77.000000   3.000000  180.000000  322.000000  163.00000   3.400000
#
#         incident  ExterQual_numeric        risk    year_born
# count  20.000000          20.000000   20.000000    20.000000
# mean    9.343300          -0.200000  385.400000  1953.750000
# std    19.203046           0.523148   45.613248     2.510504
# min     0.360000          -1.000000  299.000000  1945.000000
# 25%     1.176750          -0.250000  361.000000  1952.750000
# 50%     2.307000           0.000000  384.500000  1954.500000
# 75%     4.456250           0.000000  424.000000  1955.000000
# max    80.756000           1.000000  466.000000  1956.000000

# %% [markdown]
# # Data prep for modeling

# %%
#assess the shape before get dummies
df.shape
# Out:
# (303, 18)

# %%
# load variable name to paste into get dummies below
df.dtypes
# Out:
# age                    int64
# ca                     int64
# trestbps               int64
# chol                   int64
# thalach                int64
# oldpeak              float64
# SEX_string            object
# CP_string             object
# RESTECG_string        object
# EXANG_string          object
# FBS_string            object
# THAL_string           object
# TARGET_string         object
# Race_String           object
# incident             float64
# ExterQual_numeric      int64
# risk                   int64
# year_born              int64
# dtype: object

# %% [markdown]
# ## Managing nulls and nans

# %%
# prompt: build a new dataframe called "no_nulls_df" that will apply the mean to each null in the numerical variables and the mode to each null in the categorical variables.

# Create a copy of the DataFrame to avoid modifying the original
no_nulls_df = df.copy()

# Fill nulls in numerical columns with the mean
numerical_cols = no_nulls_df.select_dtypes(include=np.number).columns
for col in numerical_cols:
    no_nulls_df[col] = no_nulls_df[col].fillna(no_nulls_df[col].mean())

# Fill nulls in categorical columns with the mode
categorical_cols = no_nulls_df.select_dtypes(exclude=np.number).columns
for col in categorical_cols:
    no_nulls_df[col] = no_nulls_df[col].fillna(no_nulls_df[col].mode()[0])

# %%
# For the synthetic heart data, note that the dfshape with get_dummies went from 17 columns to 32 columns
no_nulls_df.shape
# Out:
# (303, 18)

# %% [markdown]
# ## Managing Categorical Variables

# %% [markdown]
# *sklearn* will not model with categorical variables.
#
# *pandas* get_dummies transform all categorical variables into a boolean (True or False). A boolean is still a catgorical variable so not helpful for sklearn.
#
# *sklearn* has its own encoding tools that transform variables into 0 representing  "False" and 1 representing "True". This is the better option.

# %%
# import sklearn for one hot encoding and test train split
# https://www.freecodecamp.org/news/how-to-build-and-train-linear-and-logistic-regression-ml-models-in-python/
import sklearn

# %%
# some categorical variables need to be transformed into numbers via one-hot encoding or get dummies.
# This is very important to do BEFORE splitting data into Testing and Training
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.get_dummies.html

# To run this, remove the '#' from the next line
# df= pd.get_dummies(data=df)

# NOTE the use of df for the dataframe name with get dummies will update the df for now on.
# If I want a unique data frame that is different from the orginal dataframe, I need a different name like 'df_model'
#,columns=["SEX_string", "CP_string", "RESTECG_string","EXANG_string","FBS_string","SLOPE_string","THAL_string","Race_String"]

# %%
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.OneHotEncoder.html
# interesting article about why one-hot encoding (ohe) is better in ML
# https://albertum.medium.com/preprocessing-onehotencoder-vs-pandas-get-dummies-3de1f3d77dcc
"""
from sklearn.preprocessing import OneHotEncoder
OneHotEncoder(
    categories='categorical_Variable_Name',  # Categories determinded automatically from a particualr feature (variable) or can be specifically delineated (see sklearn documentation link).
    drop=None, # none means not drop one of the features, this is more important for dichotomous categorical variables (e.g., click, not-click)
    sparse=True, # Will return sparse matrix if set True; a sparse matrix is more likely the more categories in the variable. "sparse matrix or sparse array is a matrix in which most of the elements are zero"
    dtype=<class 'numpy.float64'>, # Desired data type of the output; the input is a string; in most cases the ohe process is meant to make a number from strings.
    handle_unknown='error' # Whether to raise an error; good to accept the default.
)
ohe = OneHotEncoder()
transformed = ohe.fit_transform(df['categorical_Variable_Name])
print(transformed.toarray())
"""
# Out:
# '\nfrom sklearn.preprocessing import OneHotEncoder\nOneHotEncoder(\n    categories=\'categorical_Variable_Name\',  # Categories determinded automatically from a particualr feature (variable) or can be specifically delineated (see sklearn documentation link).\n    drop=None, # none means not drop one of the features, this is more important for dichotomous categorical variables (e.g., click, not-click)\n    sparse=True, # Will return sparse matrix if set True; a sparse matrix is more likely the more categories in the variable. "sparse matrix or sparse array is a matrix in which most of the elements are zero"\n    dtype=<class \'numpy.float64\'>, # Desired data type of the output; the input is a string; in most cases the ohe process is meant to make a number from strings.\n    handle_unknown=\'error\' # Whether to raise an error; good to accept the default.\n)\nohe = OneHotEncoder()\ntransformed = ohe.fit_transform(df[\'categorical_Variable_Name])\nprint(transformed.toarray())\n'

# %%
# # For initial modeling with sklearn, we remove categorical variables from no_nulls_df making num_no_nulls_df
# prompt: build a function to remove all non numerial variables from the a df and report the specific variables that are removed

def drop_non_numerical_cols(df):
    """
    Removes non-numerical columns from a Pandas DataFrame and reports the removed columns.

    Args:
        df: The input DataFrame.

    Returns:
        A tuple containing:
            - The DataFrame with non-numerical columns removed.
            - A list of the names of the removed columns.
    """
    numerical_df = df.select_dtypes(include=np.number)
    removed_cols = list(set(df.columns) - set(numerical_df.columns))
    print("\nRemoved columns: ")
    for col in removed_cols:
        print(col)
    return numerical_df, removed_cols

# %%
# For initial modeling with sklearn, we remove categorical variables from no_nulls_df making num_no_nulls_df

num_no_nulls_df, list_categorical_cols_removed = drop_non_numerical_cols(no_nulls_df)
# Out:
# Removed columns:
# THAL_string
# RESTECG_string
# SEX_string
# TARGET_string
# Race_String
# FBS_string
# CP_string
# EXANG_string

# %%
# if categorical variables are encoded, we need to use drop variables that are reporting the same data in different ways,
# EX: dichotmous variables from get_dummies like "SEX_string_male" and "SEX_string_female"
# del used above to remove one variable, but df.drop used here to remove multiple columns in one go

no_nulls_df.drop(['insert_list_of_cat_vars_here_01','insert_list_of_cat_vars_here_02'],
        axis=1, #axis 1 means columns, the drop tool can work on rows if axis=0 . . . which is the default
        inplace=True,
        errors="ignore") # if a variable in the list is not in the df, then it will not error
 # We only want numerical data for the linear regression.
  # Nominal data must be transformed using `get_dummies` or ohe.
  # Ordinal data can be transformed with get_dummies/ohe OR an ordinalEncoder
  # https://scikit-learn.org/dev/modules/generated/sklearn.preprocessing.OrdinalEncoder.html
 # all "target" variables are used for the classification analysis we can do with this data set so not needed for the regression

# %% [markdown]
# Most examples for modeling show how the data is **randomly** split into a training set (roughly 80% of the full dataset) and a testing set (the remaining 20% of the dataset).

# %%
#load test train split
from sklearn.model_selection import train_test_split

# %%
#look to see if the columsn were dropped
num_no_nulls_df.dtypes
# Out:
# age                    int64
# ca                     int64
# trestbps               int64
# chol                   int64
# thalach                int64
# oldpeak              float64
# incident             float64
# ExterQual_numeric      int64
# risk                   int64
# year_born              int64
# dtype: object

# %%
# stratified sampling
# Step 2, random sample of each DF (in this case, SEX_string == female and  SEX_string==male)
# Format from Stackoverflow
#larger, smaller = test_train_split(df, test_size=0.3)
#https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html
#sklearn.model_selection.train_test_split(*arrays, test_size=None, train_size=None, random_state=None, shuffle=True, stratify=None)
X = num_no_nulls_df.drop("incident",axis='columns')
y =num_no_nulls_df["incident"]
print(y.shape)
print(X.shape)
# for analysis on people, we would typcially want a stratified sample based on gender but that is a categorical variable and not in this example.
# stratVar=X["SEX_string"] #define the variable used for the stratified sample
# a stratified sample ensures an equal representation of a particular category (or group) is in both the training and testin dataframes
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=.2, train_size=.8, random_state=7, shuffle=True)#, stratify=stratVar)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)

#read more
# k fold stratification
#https://scikit-learn.org/stable/modules/cross_validation.html#stratification
# Out:
# (303,)
# (303, 9)
# (242, 9)
# (61, 9)
# (242,)
# (61,)

# %%
#analyze the y data (the target variable) used in the training
y_train.describe()
# Out:
# count    242.000000
# mean       5.256355
# std        9.864232
# min        0.101000
# 25%        1.421250
# 50%        2.296000
# 75%        4.304000
# max       85.169000
# Name: incident, dtype: float64

# %%
#analyze the y data (the target variable) used in the testing
y_test.describe()
# Out:
# count     61.000000
# mean       9.216656
# std       21.383688
# min        0.038000
# 25%        1.550000
# 50%        2.983000
# 75%        6.252000
# max      138.338000
# Name: incident, dtype: float64

# %% [markdown]
# # Modeling with statsmodels.api

# %%
#Load Library
# https://www.statsmodels.org/stable/api.html#regression
import statsmodels.api as sm

# %%
# if X_train has bool values, they need to be converted to numerical values of 0 or 1 for Statsmodels.api
# If string or object variables are in the data frame, then they also need to be encoded
# Convert boolean columns to numerical (0 and 1)
# prompt: build a function for a df to identify bool variables and transform them to int

def transform_bool_to_int(df):
    """
    Identifies boolean variables in a Pandas DataFrame and transforms them to integers (1 for True, 0 for False).
    Args:
        df: The input DataFrame.
    Returns:
        A DataFrame with boolean columns converted to integer type.
    """
    for col in df.columns:
        if pd.api.types.is_bool_dtype(df[col]):
            df[col] = df[col].astype(int)
    return df

# %%
# apply the transform_bool_to_int
X_train = transform_bool_to_int(X_train)
X_test = transform_bool_to_int(X_test)

# %%
# set models
# NOTE, this data is the same used in sklearn
testmodel = sm.OLS(y_train, X_train)
testmodel2 = testmodel.fit()
print(testmodel2.summary())
#this model summary provides the Coeffients for the Linear Regression
# The p-value is reported in the 'P>|t|' column.
# The p-value should be below the alpha (deault of 0.5) to be considered significant.
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               incident   R-squared:                       0.025
# Model:                            OLS   Adj. R-squared:                 -0.005
# Method:                 Least Squares   F-statistic:                    0.8413
# Date:                Mon, 21 Jul 2025   Prob (F-statistic):              0.554
# Time:                        19:25:48   Log-Likelihood:                -893.79
# No. Observations:                 242   AIC:                             1804.
# Df Residuals:                     234   BIC:                             1831.
# Df Model:                           7
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# age                  -0.0695      0.081     -0.854      0.394      -0.230       0.091
# ca                    0.0394      0.761      0.052      0.959      -1.460       1.539
# trestbps             -0.0129      0.039     -0.330      0.742      -0.090       0.064
# chol                  0.0196      0.014      1.359      0.175      -0.009       0.048
# thalach              -0.0157      0.023     -0.680      0.497      -0.061       0.030
# oldpeak               0.7533      0.749      1.005      0.316      -0.723       2.230
# ExterQual_numeric    -0.6783      1.336     -0.508      0.612      -3.311       1.954
# risk                  0.0039      0.011      0.344      0.731      -0.019       0.026
# year_born             0.0028      0.004      0.706      0.481      -0.005       0.011
# ==============================================================================
# Omnibus:                      271.099   Durbin-Watson:                   2.051
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9089.295
# Skew:                           4.782   Prob(JB):                         0.00
# Kurtosis:                      31.460   Cond. No.                     3.17e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.93e-25. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
